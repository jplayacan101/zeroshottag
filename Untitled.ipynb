# %%
import os

# %%
os.chdir('/Users/jplayacan/.cache/huggingface/datasets/downloads/extracted/8453fbfded7739b8a75b017ff719af23ed073e893f0988874aac9d45a29b54b1/ud-treebanks-v2.13/')

# %%
_UD_DATASETS = {}

for dirname in os.listdir():
    if not os.path.isdir(dirname):
        continue
    lang, dataset = dirname.replace("UD_", "").split("-")
    train, dev, test = None, None, None
    for filename in os.listdir(dirname):
        if not filename.endswith(".conllu"):
            continue
        id_, split = filename.replace(".conllu", "").split("-ud-")
        langid, dataid = id_.split("_")
        print(lang, dataset, langid, dataid, split)
        if langid not in _UD_DATASETS:
            _UD_DATASETS[langid] = {}
        if split not in _UD_DATASETS[langid]:
            _UD_DATASETS[langid][split] = []
        _UD_DATASETS[langid][split].append(os.path.join(dirname, filename))
# Out:
# Akkadian RIAO akk riao test
# Armenian ArmTDP hy armtdp train
# Armenian ArmTDP hy armtdp test
# Armenian ArmTDP hy armtdp dev
# Welsh CCG cy ccg train
# Welsh CCG cy ccg dev
# Welsh CCG cy ccg test
# Gheg GPS aln gps test
# Norwegian Nynorsk no nynorsk test
# Norwegian Nynorsk no nynorsk dev
# Norwegian Nynorsk no nynorsk train
# Old_East_Slavic TOROT orv torot test
# Old_East_Slavic TOROT orv torot train
# Old_East_Slavic TOROT orv torot dev
# English LinES en lines train
# English LinES en lines dev
# English LinES en lines test
# Albanian TSA sq tsa test
# French Sequoia fr sequoia dev
# French Sequoia fr sequoia train
# French Sequoia fr sequoia test
# Classical_Armenian CAVaL xcl caval test
# Old_East_Slavic Ruthenian orv ruthenian dev
# Old_East_Slavic Ruthenian orv ruthenian test
# Old_East_Slavic Ruthenian orv ruthenian train
# Slovenian SST sl sst test
# Slovenian SST sl sst train
# Hebrew IAHLTwiki he iahltwiki test
# Hebrew IAHLTwiki he iahltwiki dev
# Hebrew IAHLTwiki he iahltwiki train
# Guajajara TuDeT gub tudet test
# Kurmanji MG kmr mg test
# Kurmanji MG kmr mg train
# Italian PUD it pud test
# Turkish GB tr gb test
# Finnish FTB fi ftb test
# Finnish FTB fi ftb dev
# Finnish FTB fi ftb train
# Indonesian GSD id gsd test
# Indonesian GSD id gsd train
# Indonesian GSD id gsd dev
# Ukrainian IU uk iu test
# Ukrainian IU uk iu dev
# Ukrainian IU uk iu train
# English Atis en atis train
# English Atis en atis test
# English Atis en atis dev
# Dutch LassySmall nl lassysmall dev
# Dutch LassySmall nl lassysmall train
# Dutch LassySmall nl lassysmall test
# Polish PDB pl pdb test
# Polish PDB pl pdb train
# Polish PDB pl pdb dev
# Turkish Kenet tr kenet test
# Turkish Kenet tr kenet dev
# Turkish Kenet tr kenet train
# Portuguese Bosque pt bosque test
# Portuguese Bosque pt bosque dev
# Portuguese Bosque pt bosque train
# Kazakh KTB kk ktb test
# Kazakh KTB kk ktb train
# Italian PoSTWITA it postwita dev
# Italian PoSTWITA it postwita train
# Italian PoSTWITA it postwita test
# Latin ITTB la ittb test
# Latin ITTB la ittb dev
# Latin ITTB la ittb train
# Madi Jarawara jaa jarawara test
# Spanish PUD es pud test
# Buryat BDT bxr bdt test
# Buryat BDT bxr bdt train
# Italian ParlaMint it parlamint train
# Italian ParlaMint it parlamint test
# Kaapor TuDeT urb tudet test
# Korean PUD ko pud test
# Polish PUD pl pud test
# Latin Perseus la perseus train
# Latin Perseus la perseus test
# Icelandic GC is gc dev
# Icelandic GC is gc train
# Icelandic GC is gc test
# Estonian EDT et edt train
# Estonian EDT et edt test
# Estonian EDT et edt dev
# Croatian SET hr set train
# Croatian SET hr set dev
# Croatian SET hr set test
# Gothic PROIEL got proiel test
# Gothic PROIEL got proiel dev
# Gothic PROIEL got proiel train
# Old_French PROFITEROLE fro profiterole train
# Old_French PROFITEROLE fro profiterole dev
# Old_French PROFITEROLE fro profiterole test
# Turkish FrameNet tr framenet test
# Turkish FrameNet tr framenet train
# Turkish FrameNet tr framenet dev
# Latin LLCT la llct dev
# Latin LLCT la llct train
# Latin LLCT la llct test
# Swedish_Sign_Language SSLC swl sslc test
# Turkish Atis tr atis dev
# Turkish Atis tr atis train
# Turkish Atis tr atis test
# Swiss_German UZH gsw uzh test
# Middle_French PROFITEROLE frm profiterole test
# Assyrian AS aii as test
# Italian ISDT it isdt dev
# Italian ISDT it isdt train
# Italian ISDT it isdt test
# North_Sami Giella sme giella train
# North_Sami Giella sme giella test
# Norwegian Bokmaal no bokmaal dev
# Norwegian Bokmaal no bokmaal test
# Norwegian Bokmaal no bokmaal train
# French ParisStories fr parisstories train
# French ParisStories fr parisstories test
# French ParisStories fr parisstories dev
# Naija NSC pcm nsc test
# Naija NSC pcm nsc dev
# Naija NSC pcm nsc train
# English ESLSpok en eslspok dev
# English ESLSpok en eslspok test
# English ESLSpok en eslspok train
# German LIT de lit test
# Italian MarkIT it markit train
# Italian MarkIT it markit dev
# Italian MarkIT it markit test
# Latvian LVTB lv lvtb train
# Latvian LVTB lv lvtb dev
# Latvian LVTB lv lvtb test
# Chinese GSDSimp zh gsdsimp train
# Chinese GSDSimp zh gsdsimp test
# Chinese GSDSimp zh gsdsimp dev
# Irish Cadhan ga cadhan test
# Xibe XDT sjo xdt test
# Tagalog Ugnayan tl ugnayan test
# Bambara CRB bm crb test
# Lithuanian ALKSNIS lt alksnis dev
# Lithuanian ALKSNIS lt alksnis test
# Lithuanian ALKSNIS lt alksnis train
# Ancient_Greek PTNK grc ptnk train
# Ancient_Greek PTNK grc ptnk dev
# Ancient_Greek PTNK grc ptnk test
# Galician CTG gl ctg test
# Galician CTG gl ctg dev
# Galician CTG gl ctg train
# Haitian_Creole Autogramm ht autogramm test
# Chinese HK zh hk test
# Cebuano GJA ceb gja test
# Vietnamese VTB vi vtb test
# Vietnamese VTB vi vtb dev
# Vietnamese VTB vi vtb train
# Korean GSD ko gsd test
# Korean GSD ko gsd train
# Korean GSD ko gsd dev
# Amharic ATT am att test
# Greek GDT el gdt train
# Greek GDT el gdt test
# Greek GDT el gdt dev
# German HDT de hdt train
# German HDT de hdt dev
# German HDT de hdt test
# Spanish GSD es gsd test
# Spanish GSD es gsd train
# Spanish GSD es gsd dev
# Catalan AnCora ca ancora test
# Catalan AnCora ca ancora dev
# Catalan AnCora ca ancora train
# English PUD en pud test
# Russian Poetry ru poetry test
# Russian Poetry ru poetry train
# Russian Poetry ru poetry dev
# Veps VWT vep vwt test
# English EWT en ewt test
# English EWT en ewt dev
# English EWT en ewt train
# Soi AHA soj aha test
# Old_East_Slavic RNC orv rnc train
# Old_East_Slavic RNC orv rnc test
# Old_East_Slavic RNC orv rnc dev
# Swedish LinES sv lines dev
# Swedish LinES sv lines test
# Swedish LinES sv lines train
# Yupik SLI ess sli test
# Russian SynTagRus ru syntagrus dev
# Russian SynTagRus ru syntagrus test
# Russian SynTagRus ru syntagrus train
# Czech PDT cs pdt dev
# Czech PDT cs pdt train
# Czech PDT cs pdt test
# Beja NSC bej nsc test
# Italian VIT it vit test
# Italian VIT it vit dev
# Italian VIT it vit train
# Erzya JR myv jr train
# Erzya JR myv jr test
# Macedonian MTB mk mtb test
# Armenian BSUT hy bsut train
# Armenian BSUT hy bsut dev
# Armenian BSUT hy bsut test
# Bhojpuri BHTB bho bhtb test
# Polish LFG pl lfg dev
# Polish LFG pl lfg train
# Polish LFG pl lfg test
# Zaar Autogramm say autogramm test
# Umbrian IKUVINA xum ikuvina test
# Thai PUD th pud test
# Marathi UFAL mr ufal train
# Marathi UFAL mr ufal dev
# Marathi UFAL mr ufal test
# Basque BDT eu bdt test
# Basque BDT eu bdt dev
# Basque BDT eu bdt train
# Slovak SNK sk snk dev
# Slovak SNK sk snk train
# Slovak SNK sk snk test
# Javanese CSUI jv csui test
# Kiche IU quc iu test
# English GENTLE en gentle test
# Japanese GSDLUW ja gsdluw train
# Japanese GSDLUW ja gsdluw dev
# Japanese GSDLUW ja gsdluw test
# Russian Taiga ru taiga test
# Russian Taiga ru taiga dev
# Russian Taiga ru taiga train
# Guarani OldTuDeT gn oldtudet test
# Yoruba YTB yo ytb test
# Warlpiri UFAL wbp ufal test
# Low_Saxon LSDC nds lsdc test
# English Pronouns en pronouns test
# Finnish OOD fi ood test
# Tamil TTB ta ttb train
# Tamil TTB ta ttb dev
# Tamil TTB ta ttb test
# Georgian GLC ka glc test
# Spanish AnCora es ancora train
# Spanish AnCora es ancora test
# Spanish AnCora es ancora dev
# Maltese MUDT mt mudt test
# Maltese MUDT mt mudt train
# Maltese MUDT mt mudt dev
# Finnish TDT fi tdt train
# Finnish TDT fi tdt dev
# Finnish TDT fi tdt test
# French Rhapsodie fr rhapsodie dev
# French Rhapsodie fr rhapsodie train
# French Rhapsodie fr rhapsodie test
# Nheengatu CompLin yrl complin test
# Old_Irish DipSGG sga dipsgg test
# Indonesian CSUI id csui train
# Indonesian CSUI id csui test
# Ancient_Greek Perseus grc perseus dev
# Ancient_Greek Perseus grc perseus test
# Ancient_Greek Perseus grc perseus train
# Old_East_Slavic Birchbark orv birchbark dev
# Old_East_Slavic Birchbark orv birchbark test
# Old_East_Slavic Birchbark orv birchbark train
# Ancient_Hebrew PTNK hbo ptnk train
# Ancient_Hebrew PTNK hbo ptnk test
# Ancient_Hebrew PTNK hbo ptnk dev
# Tatar NMCTT tt nmctt test
# Icelandic IcePaHC is icepahc train
# Icelandic IcePaHC is icepahc test
# Icelandic IcePaHC is icepahc dev
# Mbya_Guarani Thomas gun thomas test
# Urdu UDTB ur udtb train
# Urdu UDTB ur udtb dev
# Urdu UDTB ur udtb test
# Romanian RRT ro rrt dev
# Romanian RRT ro rrt test
# Romanian RRT ro rrt train
# Tagalog TRG tl trg test
# Akkadian PISANDUB akk pisandub test
# Latin PROIEL la proiel train
# Latin PROIEL la proiel test
# Latin PROIEL la proiel dev
# Persian PerDT fa perdt test
# Persian PerDT fa perdt train
# Persian PerDT fa perdt dev
# Apurina UFPA apu ufpa test
# Sinhala STB si stb test
# Indonesian PUD id pud test
# French ParTUT fr partut train
# French ParTUT fr partut dev
# French ParTUT fr partut test
# Icelandic Modern is modern train
# Icelandic Modern is modern test
# Icelandic Modern is modern dev
# Hungarian Szeged hu szeged train
# Hungarian Szeged hu szeged test
# Hungarian Szeged hu szeged dev
# Hindi HDTB hi hdtb test
# Hindi HDTB hi hdtb train
# Hindi HDTB hi hdtb dev
# Classical_Chinese Kyoto lzh kyoto dev
# Classical_Chinese Kyoto lzh kyoto train
# Classical_Chinese Kyoto lzh kyoto test
# Komi_Permyak UH koi uh test
# Komi_Permyak UH koi uh train
# Chinese CFL zh cfl test
# Faroese FarPaHC fo farpahc dev
# Faroese FarPaHC fo farpahc test
# Faroese FarPaHC fo farpahc train
# Sanskrit Vedic sa vedic test
# Sanskrit Vedic sa vedic train
# Turkish IMST tr imst dev
# Turkish IMST tr imst test
# Turkish IMST tr imst train
# Portuguese Porttinari pt porttinari test
# Portuguese Porttinari pt porttinari train
# Portuguese Porttinari pt porttinari dev
# Lithuanian HSE lt hse train
# Lithuanian HSE lt hse dev
# Lithuanian HSE lt hse test
# Slovenian SSJ sl ssj test
# Slovenian SSJ sl ssj train
# Slovenian SSJ sl ssj dev
# Livvi KKPP olo kkpp test
# Livvi KKPP olo kkpp train
# Swedish Talbanken sv talbanken test
# Swedish Talbanken sv talbanken dev
# Swedish Talbanken sv talbanken train
# Arabic NYUAD ar nyuad train
# Arabic NYUAD ar nyuad dev
# Arabic NYUAD ar nyuad test
# English GUMReddit en gumreddit train
# English GUMReddit en gumreddit test
# English GUMReddit en gumreddit dev
# Italian ParTUT it partut train
# Italian ParTUT it partut test
# Italian ParTUT it partut dev
# Czech FicTree cs fictree train
# Czech FicTree cs fictree test
# Czech FicTree cs fictree dev
# Wolof WTB wo wtb test
# Wolof WTB wo wtb dev
# Wolof WTB wo wtb train
# Bulgarian BTB bg btb test
# Bulgarian BTB bg btb train
# Bulgarian BTB bg btb dev
# Russian PUD ru pud test
# Portuguese PUD pt pud test
# Romanian ArT ro art test
# Bororo BDT bor bdt test
# Akuntsu TuDeT aqz tudet test
# Portuguese PetroGold pt petrogold train
# Portuguese PetroGold pt petrogold test
# Portuguese PetroGold pt petrogold dev
# Makurap TuDeT mpu tudet test
# Turkish Penn tr penn train
# Turkish Penn tr penn dev
# Turkish Penn tr penn test
# Chinese Beginner zh beginner test
# Kangri KDTB xnr kdtb test
# Italian Valico it valico test
# Malayalam UFAL ml ufal test
# Japanese BCCWJ ja bccwj train
# Japanese BCCWJ ja bccwj test
# Japanese BCCWJ ja bccwj dev
# Bengali BRU bn bru test
# Italian TWITTIRO it twittiro test
# Italian TWITTIRO it twittiro train
# Italian TWITTIRO it twittiro dev
# Ancient_Greek PROIEL grc proiel dev
# Ancient_Greek PROIEL grc proiel train
# Ancient_Greek PROIEL grc proiel test
# Breton KEB br keb test
# Czech CAC cs cac train
# Czech CAC cs cac test
# Czech CAC cs cac dev
# Japanese GSD ja gsd train
# Japanese GSD ja gsd test
# Japanese GSD ja gsd dev
# Neapolitan RB nap rb test
# Telugu MTG te mtg train
# Telugu MTG te mtg test
# Telugu MTG te mtg dev
# Italian Old it old train
# Italian Old it old test
# Italian Old it old dev
# Korean Kaist ko kaist train
# Korean Kaist ko kaist dev
# Korean Kaist ko kaist test
# Cantonese HK yue hk test
# Turkish_German SAGT qtd sagt test
# Turkish_German SAGT qtd sagt dev
# Turkish_German SAGT qtd sagt train
# Teko TuDeT eme tudet test
# English GUM en gum dev
# English GUM en gum test
# English GUM en gum train
# Chinese PUD zh pud test
# Pomak Philotis qpm philotis dev
# Pomak Philotis qpm philotis train
# Pomak Philotis qpm philotis test
# Romanian Nonstandard ro nonstandard test
# Romanian Nonstandard ro nonstandard train
# Romanian Nonstandard ro nonstandard dev
# German GSD de gsd train
# German GSD de gsd dev
# German GSD de gsd test
# Old_Church_Slavonic PROIEL cu proiel dev
# Old_Church_Slavonic PROIEL cu proiel test
# Old_Church_Slavonic PROIEL cu proiel train
# Karelian KKPP krl kkpp test
# Maghrebi_Arabic_French Arabizi qaf arabizi dev
# Maghrebi_Arabic_French Arabizi qaf arabizi train
# Maghrebi_Arabic_French Arabizi qaf arabizi test
# Portuguese CINTIL pt cintil test
# Portuguese CINTIL pt cintil train
# Portuguese CINTIL pt cintil dev
# French PUD fr pud test
# Upper_Sorbian UFAL hsb ufal train
# Upper_Sorbian UFAL hsb ufal test
# Danish DDT da ddt train
# Danish DDT da ddt dev
# Danish DDT da ddt test
# Highland_Puebla_Nahuatl ITML azz itml test
# Icelandic PUD is pud test
# Galician TreeGal gl treegal test
# Galician TreeGal gl treegal train
# Hindi PUD hi pud test
# Japanese PUDLUW ja pudluw test
# South_Levantine_Arabic MADAR ajp madar test
# Komi_Zyrian Lattice kpv lattice train
# Komi_Zyrian Lattice kpv lattice test
# Western_Sierra_Puebla_Nahuatl ITML nhi itml test
# Sanskrit UFAL sa ufal test
# Tamil MWTT ta mwtt test
# Turkish PUD tr pud test
# Irish IDT ga idt test
# Irish IDT ga idt train
# Irish IDT ga idt dev
# Czech Poetry cs poetry test
# Faroese OFT fo oft test
# Nayini AHA nyq aha test
# Frisian_Dutch Fame qfn fame test
# Munduruku TuDeT myu tudet test
# Hittite HitTB hit hittb test
# Manx Cadhan gv cadhan test
# Manx Cadhan gv cadhan train
# Kyrgyz KTMU ky ktmu train
# Kyrgyz KTMU ky ktmu test
# Skolt_Sami Giellagas sms giellagas test
# Skolt_Sami Giellagas sms giellagas train
# Finnish PUD fi pud test
# Mbya_Guarani Dooley gun dooley test
# Persian Seraji fa seraji test
# Persian Seraji fa seraji dev
# Persian Seraji fa seraji train
# Ligurian GLT lij glt train
# Ligurian GLT lij glt test
# Afrikaans AfriBooms af afribooms dev
# Afrikaans AfriBooms af afribooms test
# Afrikaans AfriBooms af afribooms train
# Japanese PUD ja pud test
# Czech CLTT cs cltt train
# Czech CLTT cs cltt test
# Czech CLTT cs cltt dev
# French GSD fr gsd dev
# French GSD fr gsd train
# French GSD fr gsd test
# Karo TuDeT arr tudet test
# German PUD de pud test
# Irish TwittIrish ga twittirish test
# Irish TwittIrish ga twittirish dev
# Irish TwittIrish ga twittirish train
# Dutch Alpino nl alpino train
# Dutch Alpino nl alpino test
# Dutch Alpino nl alpino dev
# Swedish PUD sv pud test
# Chinese GSD zh gsd train
# Chinese GSD zh gsd test
# Chinese GSD zh gsd dev
# Old_Turkish Tonqq otk tonqq test
# Romanian SiMoNERo ro simonero dev
# Romanian SiMoNERo ro simonero train
# Romanian SiMoNERo ro simonero test
# Arabic PUD ar pud test
# Tupinamba TuDeT tpn tudet test
# Belarusian HSE be hse train
# Belarusian HSE be hse dev
# Belarusian HSE be hse test
# Coptic Scriptorium cop scriptorium train
# Coptic Scriptorium cop scriptorium dev
# Coptic Scriptorium cop scriptorium test
# Yakut YKTDT sah yktdt test
# French FQB fr fqb test
# Abaza ATB abq atb test
# Komi_Zyrian IKDP kpv ikdp test
# Serbian SET sr set train
# Serbian SET sr set dev
# Serbian SET sr set test
# Turkish Tourism tr tourism test
# Turkish Tourism tr tourism train
# Turkish Tourism tr tourism dev
# Estonian EWT et ewt test
# Estonian EWT et ewt dev
# Estonian EWT et ewt train
# Moksha JR mdf jr test
# Moksha JR mdf jr train
# Western_Armenian ArmTDP hyw armtdp test
# Western_Armenian ArmTDP hyw armtdp dev
# Western_Armenian ArmTDP hyw armtdp train
# Czech PUD cs pud test
# Old_Irish DipWBG sga dipwbg test
# Scottish_Gaelic ARCOSG gd arcosg dev
# Scottish_Gaelic ARCOSG gd arcosg train
# Scottish_Gaelic ARCOSG gd arcosg test
# Portuguese GSD pt gsd dev
# Portuguese GSD pt gsd train
# Portuguese GSD pt gsd test
# Chinese PatentChar zh patentchar test
# Russian GSD ru gsd test
# Russian GSD ru gsd train
# Russian GSD ru gsd dev
# Khunsari AHA kfm aha test
# Turkish BOUN tr boun test
# Turkish BOUN tr boun train
# Turkish BOUN tr boun dev
# Arabic PADT ar padt dev
# Arabic PADT ar padt train
# Arabic PADT ar padt test
# Hebrew HTB he htb dev
# Hebrew HTB he htb train
# Hebrew HTB he htb test
# Greek GUD el gud test
# Greek GUD el gud train
# English ParTUT en partut test
# English ParTUT en partut train
# English ParTUT en partut dev
# Uyghur UDT ug udt test
# Uyghur UDT ug udt train
# Uyghur UDT ug udt dev
# Latin UDante la udante train
# Latin UDante la udante dev
# Latin UDante la udante test
# Japanese BCCWJLUW ja bccwjluw train
# Japanese BCCWJLUW ja bccwjluw dev
# Japanese BCCWJLUW ja bccwjluw test
# Chukchi HSE ckt hse test
# Xavante XDT xav xdt test

# %%
cwd = os.getcwd()

# Printing the current working directory
print("Th Current working directory is: {0}".format(cwd))
# Out:
# Th Current working directory is: /Users/jplayacan/.cache/huggingface/datasets/downloads/extracted/8453fbfded7739b8a75b017ff719af23ed073e893f0988874aac9d45a29b54b1/ud-treebanks-v2.13

# %%
print(_UD_DATASETS)
# Out:
# {'akk': {'test': ['UD_Akkadian-RIAO/akk_riao-ud-test.conllu', 'UD_Akkadian-PISANDUB/akk_pisandub-ud-test.conllu']}, 'hy': {'train': ['UD_Armenian-ArmTDP/hy_armtdp-ud-train.conllu', 'UD_Armenian-BSUT/hy_bsut-ud-train.conllu'], 'test': ['UD_Armenian-ArmTDP/hy_armtdp-ud-test.conllu', 'UD_Armenian-BSUT/hy_bsut-ud-test.conllu'], 'dev': ['UD_Armenian-ArmTDP/hy_armtdp-ud-dev.conllu', 'UD_Armenian-BSUT/hy_bsut-ud-dev.conllu']}, 'cy': {'train': ['UD_Welsh-CCG/cy_ccg-ud-train.conllu'], 'dev': ['UD_Welsh-CCG/cy_ccg-ud-dev.conllu'], 'test': ['UD_Welsh-CCG/cy_ccg-ud-test.conllu']}, 'aln': {'test': ['UD_Gheg-GPS/aln_gps-ud-test.conllu']}, 'no': {'test': ['UD_Norwegian-Nynorsk/no_nynorsk-ud-test.conllu', 'UD_Norwegian-Bokmaal/no_bokmaal-ud-test.conllu'], 'dev': ['UD_Norwegian-Nynorsk/no_nynorsk-ud-dev.conllu', 'UD_Norwegian-Bokmaal/no_bokmaal-ud-dev.conllu'], 'train': ['UD_Norwegian-Nynorsk/no_nynorsk-ud-train.conllu', 'UD_Norwegian-Bokmaal/no_bokmaal-ud-train.conllu']}, 'orv': {'test': ['UD_Old_East_Slavic-TOROT/orv_torot-ud-test.conllu', 'UD_Old_East_Slavic-Ruthenian/orv_ruthenian-ud-test.conllu', 'UD_Old_East_Slavic-RNC/orv_rnc-ud-test.conllu', 'UD_Old_East_Slavic-Birchbark/orv_birchbark-ud-test.conllu'], 'train': ['UD_Old_East_Slavic-TOROT/orv_torot-ud-train.conllu', 'UD_Old_East_Slavic-Ruthenian/orv_ruthenian-ud-train.conllu', 'UD_Old_East_Slavic-RNC/orv_rnc-ud-train.conllu', 'UD_Old_East_Slavic-Birchbark/orv_birchbark-ud-train.conllu'], 'dev': ['UD_Old_East_Slavic-TOROT/orv_torot-ud-dev.conllu', 'UD_Old_East_Slavic-Ruthenian/orv_ruthenian-ud-dev.conllu', 'UD_Old_East_Slavic-RNC/orv_rnc-ud-dev.conllu', 'UD_Old_East_Slavic-Birchbark/orv_birchbark-ud-dev.conllu']}, 'en': {'train': ['UD_English-LinES/en_lines-ud-train.conllu', 'UD_English-Atis/en_atis-ud-train.conllu', 'UD_English-ESLSpok/en_eslspok-ud-train.conllu', 'UD_English-EWT/en_ewt-ud-train.conllu', 'UD_English-GUMReddit/en_gumreddit-ud-train.conllu', 'UD_English-GUM/en_gum-ud-train.conllu', 'UD_English-ParTUT/en_partut-ud-train.conllu'], 'dev': ['UD_English-LinES/en_lines-ud-dev.conllu', 'UD_English-Atis/en_atis-ud-dev.conllu', 'UD_English-ESLSpok/en_eslspok-ud-dev.conllu', 'UD_English-EWT/en_ewt-ud-dev.conllu', 'UD_English-GUMReddit/en_gumreddit-ud-dev.conllu', 'UD_English-GUM/en_gum-ud-dev.conllu', 'UD_English-ParTUT/en_partut-ud-dev.conllu'], 'test': ['UD_English-LinES/en_lines-ud-test.conllu', 'UD_English-Atis/en_atis-ud-test.conllu', 'UD_English-ESLSpok/en_eslspok-ud-test.conllu', 'UD_English-PUD/en_pud-ud-test.conllu', 'UD_English-EWT/en_ewt-ud-test.conllu', 'UD_English-GENTLE/en_gentle-ud-test.conllu', 'UD_English-Pronouns/en_pronouns-ud-test.conllu', 'UD_English-GUMReddit/en_gumreddit-ud-test.conllu', 'UD_English-GUM/en_gum-ud-test.conllu', 'UD_English-ParTUT/en_partut-ud-test.conllu']}, 'sq': {'test': ['UD_Albanian-TSA/sq_tsa-ud-test.conllu']}, 'fr': {'dev': ['UD_French-Sequoia/fr_sequoia-ud-dev.conllu', 'UD_French-ParisStories/fr_parisstories-ud-dev.conllu', 'UD_French-Rhapsodie/fr_rhapsodie-ud-dev.conllu', 'UD_French-ParTUT/fr_partut-ud-dev.conllu', 'UD_French-GSD/fr_gsd-ud-dev.conllu'], 'train': ['UD_French-Sequoia/fr_sequoia-ud-train.conllu', 'UD_French-ParisStories/fr_parisstories-ud-train.conllu', 'UD_French-Rhapsodie/fr_rhapsodie-ud-train.conllu', 'UD_French-ParTUT/fr_partut-ud-train.conllu', 'UD_French-GSD/fr_gsd-ud-train.conllu'], 'test': ['UD_French-Sequoia/fr_sequoia-ud-test.conllu', 'UD_French-ParisStories/fr_parisstories-ud-test.conllu', 'UD_French-Rhapsodie/fr_rhapsodie-ud-test.conllu', 'UD_French-ParTUT/fr_partut-ud-test.conllu', 'UD_French-PUD/fr_pud-ud-test.conllu', 'UD_French-GSD/fr_gsd-ud-test.conllu', 'UD_French-FQB/fr_fqb-ud-test.conllu']}, 'xcl': {'test': ['UD_Classical_Armenian-CAVaL/xcl_caval-ud-test.conllu']}, 'sl': {'test': ['UD_Slovenian-SST/sl_sst-ud-test.conllu', 'UD_Slovenian-SSJ/sl_ssj-ud-test.conllu'], 'train': ['UD_Slovenian-SST/sl_sst-ud-train.conllu', 'UD_Slovenian-SSJ/sl_ssj-ud-train.conllu'], 'dev': ['UD_Slovenian-SSJ/sl_ssj-ud-dev.con ...

# %%
_UD_DATASETS = {}
for dirname in os.listdir('/Users/jplayacan/.cache/huggingface/datasets/downloads/extracted/8453fbfded7739b8a75b017ff719af23ed073e893f0988874aac9d45a29b54b1/ud-treebanks-v2.13/'):
    if not os.path.isdir(dirname):
        continue
    lang, dataset = dirname.replace("UD_", "").split("-")
    train, dev, test = None, None, None
    for filename in os.listdir(dirname):
        if not filename.endswith(".conllu"):
            continue
        id_, split = filename.replace(".conllu", "").split("-ud-")
        langid, dataid = id_.split("_")
        print(lang, dataset, langid, dataid, split)
        if langid not in _UD_DATASETS:
            _UD_DATASETS[langid] = {}
        if split not in _UD_DATASETS[langid]:
            _UD_DATASETS[langid][split] = []
        _UD_DATASETS[langid][split].append(os.path.join(dirname, filename))

# %%
_UD_DATASETS
# Out:
# {}

# %%
os.listdir('/Users/jplayacan/.cache/huggingface/datasets/downloads/extracted/8453fbfded7739b8a75b017ff719af23ed073e893f0988874aac9d45a29b54b1/ud-treebanks-v2.13/')
# Out:
# ['UD_Akkadian-RIAO',
#  'UD_Armenian-ArmTDP',
#  'UD_Welsh-CCG',
#  'UD_Gheg-GPS',
#  'UD_Norwegian-Nynorsk',
#  'UD_Old_East_Slavic-TOROT',
#  'UD_English-LinES',
#  'UD_Albanian-TSA',
#  'UD_French-Sequoia',
#  'UD_Classical_Armenian-CAVaL',
#  'UD_Old_East_Slavic-Ruthenian',
#  'UD_Slovenian-SST',
#  'UD_Hebrew-IAHLTwiki',
#  'UD_Guajajara-TuDeT',
#  'UD_Kurmanji-MG',
#  'UD_Italian-PUD',
#  'UD_Turkish-GB',
#  'UD_Finnish-FTB',
#  'UD_Indonesian-GSD',
#  'UD_Ukrainian-IU',
#  'UD_English-Atis',
#  'UD_Dutch-LassySmall',
#  'UD_Polish-PDB',
#  'UD_Turkish-Kenet',
#  'UD_Portuguese-Bosque',
#  'UD_Kazakh-KTB',
#  'UD_Italian-PoSTWITA',
#  'UD_Latin-ITTB',
#  'UD_Madi-Jarawara',
#  'UD_Spanish-PUD',
#  'UD_Buryat-BDT',
#  'UD_Italian-ParlaMint',
#  'UD_Kaapor-TuDeT',
#  'UD_Korean-PUD',
#  'UD_Polish-PUD',
#  'UD_Latin-Perseus',
#  'UD_Icelandic-GC',
#  'UD_Estonian-EDT',
#  'UD_Croatian-SET',
#  'UD_Gothic-PROIEL',
#  'UD_Old_French-PROFITEROLE',
#  'UD_Turkish-FrameNet',
#  'UD_Latin-LLCT',
#  'UD_Swedish_Sign_Language-SSLC',
#  'UD_Turkish-Atis',
#  'UD_Swiss_German-UZH',
#  'UD_Middle_French-PROFITEROLE',
#  'UD_Assyrian-AS',
#  'UD_Italian-ISDT',
#  'UD_North_Sami-Giella',
#  'UD_Norwegian-Bokmaal',
#  'UD_French-ParisStories',
#  'UD_Naija-NSC',
#  'UD_English-ESLSpok',
#  'UD_German-LIT',
#  'UD_Italian-MarkIT',
#  'UD_Latvian-LVTB',
#  'UD_Chinese-GSDSimp',
#  'UD_Irish-Cadhan',
#  'UD_Xibe-XDT',
#  'UD_Tagalog-Ugnayan',
#  'UD_Bambara-CRB',
#  'UD_Lithuanian-ALKSNIS',
#  'UD_Ancient_Greek-PTNK',
#  'UD_Galician-CTG',
#  'UD_Haitian_Creole-Autogramm',
#  'UD_Chinese-HK',
#  'UD_Cebuano-GJA',
#  'UD_Vietnamese-VTB',
#  'UD_Korean-GSD',
#  'UD_Amharic-ATT',
#  'UD_Greek-GDT',
#  'UD_German-HDT',
#  'UD_Spanish-GSD',
#  'UD_Catalan-AnCora',
#  'UD_English-PUD',
#  'UD_Russian-Poetry',
#  'UD_Veps-VWT',
#  'UD_English-EWT',
#  'UD_Soi-AHA',
#  'UD_Old_East_Slavic-RNC',
#  'UD_Swedish-LinES',
#  'UD_Yupik-SLI',
#  'UD_Russian-SynTagRus',
#  'UD_Czech-PDT',
#  'UD_Beja-NSC',
#  'UD_Italian-VIT',
#  'UD_Erzya-JR',
#  'UD_Macedonian-MTB',
#  'UD_Armenian-BSUT',
#  'UD_Bhojpuri-BHTB',
#  'UD_Polish-LFG',
#  'UD_Zaar-Autogramm',
#  'UD_Umbrian-IKUVINA',
#  'UD_Thai-PUD',
#  'UD_Marathi-UFAL',
#  'UD_Basque-BDT',
#  'UD_Slovak-SNK',
#  'UD_Javanese-CSUI',
#  'UD_Kiche-IU',
#  'UD_English-GENTLE',
#  'UD_Japanese-GSDLUW',
#  'UD_Russian-Taiga',
#  'UD_Guarani-OldTuDeT',
#  'UD_Yoruba-YTB',
#  'UD_Warlpiri-UFAL',
#  'UD_Low_Saxon-LSDC',
#  'UD_English-Pronouns',
#  'UD_Finnish-OOD',
#  'UD_Tamil-TTB',
#  'UD_Georgian-GLC',
#  'UD_Spanish-AnCora',
#  'UD_Maltese-MUDT',
#  'UD_Finnish-TDT',
#  'UD_French-Rhapsodie',
#  'UD_Nheengatu-CompLin',
#  'UD_Old_Irish-DipSGG',
#  'UD_Indonesian-CSUI',
#  'UD_Ancient_Greek-Perseus',
#  'UD_Old_East_Slavic-Birchbark',
#  'UD_Ancient_Hebrew-PTNK',
#  'UD_Tatar-NMCTT',
#  'UD_Icelandic-IcePaHC',
#  'UD_Mbya_Guarani-Thomas',
#  'UD_Urdu-UDTB',
#  'UD_Romanian-RRT',
#  'UD_Tagalog-TRG',
#  'UD_Akkadian-PISANDUB',
#  'UD_Latin-PROIEL',
#  'UD_Persian-PerDT',
#  'UD_Apurina-UFPA',
#  'UD_Sinhala-STB',
#  'UD_Indonesian-PUD',
#  'UD_French-ParTUT',
#  'UD_Icelandic-Modern',
#  'UD_Hungarian-Szeged',
#  'UD_Hindi-HDTB',
#  'UD_Classical_Chinese-Kyoto',
#  'UD_Komi_Permyak-UH',
#  'UD_Chinese-CFL',
#  'UD_Faroese-FarPaHC',
#  'UD_Sanskrit-Vedic',
#  'UD_Turkish-IMST',
#  'UD_Portuguese-Porttinari',
#  'UD_Lithuanian-HSE',
#  'UD_Slovenian-SSJ',
#  'UD_Livvi-KKPP',
#  'UD_Swedish-Talbanken',
#  'UD_Arabic-NYUAD',
#  'UD_English-GUMReddit',
#  'UD_Italian-ParTUT',
#  'UD_Czech-FicTree',
#  'UD_Wolof-WTB',
#  'UD_Bulgarian-BTB',
#  'UD_Russian-PUD',
#  'UD_Portuguese-PUD',
#  'UD_Romanian-ArT',
#  'UD_Bororo-BDT',
#  'UD_Akuntsu-TuDeT',
#  'UD_Portuguese-PetroGold',
#  'UD_Makurap-TuDeT',
#  'UD_Turkish-Penn',
#  'UD_Chinese-Beginner',
#  'UD_Kangri-KDTB',
#  'UD_Italian-Valico',
#  'UD_Malayalam-UFAL',
#  'UD_Japanese-BCCWJ',
#  'UD_Bengali-BRU',
#  'UD_Italian-TWITTIRO',
#  'UD_Ancient_Greek-PROIEL',
#  'UD_Breton-KEB',
#  'UD_Czech-CAC',
#  'UD_Japanese-GSD',
#  'UD_Neapolitan-RB',
#  'UD_Telugu-MTG',
#  'UD_Italian-Old',
#  'UD_Korean-Kaist',
#  'UD_Cantonese-HK',
#  'UD_Turkish_German-SAGT',
#  'UD_Teko-TuDeT',
#  'UD_English-GUM',
#  'UD_Chinese-PUD',
#  'UD_Pomak-Philotis',
#  'UD_Romanian-Nonstandard',
#  'UD_German-GSD',
#  'UD_Old_Church_Slavonic-PROIEL',
#  'UD_Karelian-KKPP',
#  'UD_Maghrebi_Arabic_French-Arabizi',
#  'UD_Portuguese-CINTIL',
#  'UD_French-PUD',
#  'UD_Upper_Sorbian-UFAL',
#  'UD_Danish-DDT',
#  'UD_Highland_Puebla_Nahuatl-ITML',
#  'UD_Icelandic-PUD',
#  'UD_Galician-TreeGal',
#  'UD_Hindi-PUD',
#  'UD_Japanese-PUDLUW',
#  'UD_South_Levantine_Arabic-MADAR',
#  'UD_Komi_Zyrian-Lattice',
#  'UD_Western_Sierra_Puebla_Nahuatl-ITML',
#  'UD_Sanskrit-UFAL',
#  'UD_Tamil-MWTT',
#  'UD_Turkish-PUD',
#  'UD_Irish-IDT',
#  'UD_Czech-Poetry',
#  'UD_Faroese-OFT',
#  'UD_Nayini-AHA',
#  'UD_Frisian_Dutch-Fame',
#  'UD_Munduruku-TuDeT',
#  'UD_Hittite-HitTB',
#  'UD_Manx-Cadhan',
#  'UD_Kyrgyz-KTMU',
#  'UD_Skolt_Sami-Giellagas',
#  'UD_Finnish-PUD',
#  'UD_Mbya_Guarani-Dooley',
#  'UD_Persian-Seraji',
#  'UD_Ligurian-GLT',
#  'UD_Afrikaans-AfriBooms',
#  'UD_Japanese-PUD',
#  'UD_Czech-CLTT',
#  'UD_French-GSD',
#  'UD_Karo-TuDeT',
#  'UD_German-PUD',
#  'UD_Irish-TwittIrish',
#  'UD_Dutch-Alpino',
#  'UD_Swedish-PUD',
#  'UD_Chinese-GSD',
#  'UD_Old_Turkish-Tonqq',
#  'UD_Romanian-SiMoNERo',
#  'UD_Arabic-PUD',
#  'UD_Tupinamba-TuDeT',
#  'UD_Belarusian-HSE',
#  'UD_Coptic-Scriptorium',
#  'UD_Yakut-YKTDT',
#  'UD_French-FQB',
#  'UD_Abaza-ATB',
#  'UD_Komi_Zyrian-IKDP',
#  'UD_Serbian-SET',
#  'UD_Turkish-Tourism',
#  'UD_Estonian-EWT',
#  'UD_Moksha-JR',
#  'UD_Western_Armenian-ArmTDP',
#  'UD_Czech-PUD',
#  'UD_Old_Irish-DipWBG',
#  'UD_Scottish_Gaelic-ARCOSG',
#  'UD_Portuguese-GSD',
#  'UD_Chinese-PatentChar',
#  'UD_Russian-GSD',
#  'UD_Khunsari-AHA',
#  'UD_Turkish-BOUN',
#  'UD_Arabic-PADT',
#  'UD_Hebrew-HTB',
#  'UD_Greek-GUD',
#  'UD_English-ParTUT',
#  'UD_Uyghur-UDT',
#  'UD_Latin-UDante',
#  'UD_Japanese-BCCWJLUW',
#  'UD_Chukchi-HSE',
#  'UD_Xavante-XDT']

# %%
import os

original_directory = os.getcwd()

new_directory = '/Users/jplayacan/.cache/huggingface/datasets/downloads/extracted/8453fbfded7739b8a75b017ff719af23ed073e893f0988874aac9d45a29b54b1/ud-treebanks-v2.13/'
os.chdir(new_directory)

_UD_DATASETS = {}
for dirname in os.listdir():
    if not os.path.isdir(dirname):
        continue
    lang, dataset = dirname.replace("UD_", "").split("-")
    train, dev, test = None, None, None
    for filename in os.listdir(dirname):
        if not filename.endswith(".conllu"):
            continue
        id_, split = filename.replace(".conllu", "").split("-ud-")
        langid, dataid = id_.split("_")
        print(lang, dataset, langid, dataid, split)
        if langid not in _UD_DATASETS:
            _UD_DATASETS[langid] = {}
        if split not in _UD_DATASETS[langid]:
            _UD_DATASETS[langid][split] = []
        _UD_DATASETS[langid][split].append(os.path.join(dirname, filename))


os.chdir(original_directory)
# Out:
# Akkadian RIAO akk riao test
# Armenian ArmTDP hy armtdp train
# Armenian ArmTDP hy armtdp test
# Armenian ArmTDP hy armtdp dev
# Welsh CCG cy ccg train
# Welsh CCG cy ccg dev
# Welsh CCG cy ccg test
# Gheg GPS aln gps test
# Norwegian Nynorsk no nynorsk test
# Norwegian Nynorsk no nynorsk dev
# Norwegian Nynorsk no nynorsk train
# Old_East_Slavic TOROT orv torot test
# Old_East_Slavic TOROT orv torot train
# Old_East_Slavic TOROT orv torot dev
# English LinES en lines train
# English LinES en lines dev
# English LinES en lines test
# Albanian TSA sq tsa test
# French Sequoia fr sequoia dev
# French Sequoia fr sequoia train
# French Sequoia fr sequoia test
# Classical_Armenian CAVaL xcl caval test
# Old_East_Slavic Ruthenian orv ruthenian dev
# Old_East_Slavic Ruthenian orv ruthenian test
# Old_East_Slavic Ruthenian orv ruthenian train
# Slovenian SST sl sst test
# Slovenian SST sl sst train
# Hebrew IAHLTwiki he iahltwiki test
# Hebrew IAHLTwiki he iahltwiki dev
# Hebrew IAHLTwiki he iahltwiki train
# Guajajara TuDeT gub tudet test
# Kurmanji MG kmr mg test
# Kurmanji MG kmr mg train
# Italian PUD it pud test
# Turkish GB tr gb test
# Finnish FTB fi ftb test
# Finnish FTB fi ftb dev
# Finnish FTB fi ftb train
# Indonesian GSD id gsd test
# Indonesian GSD id gsd train
# Indonesian GSD id gsd dev
# Ukrainian IU uk iu test
# Ukrainian IU uk iu dev
# Ukrainian IU uk iu train
# English Atis en atis train
# English Atis en atis test
# English Atis en atis dev
# Dutch LassySmall nl lassysmall dev
# Dutch LassySmall nl lassysmall train
# Dutch LassySmall nl lassysmall test
# Polish PDB pl pdb test
# Polish PDB pl pdb train
# Polish PDB pl pdb dev
# Turkish Kenet tr kenet test
# Turkish Kenet tr kenet dev
# Turkish Kenet tr kenet train
# Portuguese Bosque pt bosque test
# Portuguese Bosque pt bosque dev
# Portuguese Bosque pt bosque train
# Kazakh KTB kk ktb test
# Kazakh KTB kk ktb train
# Italian PoSTWITA it postwita dev
# Italian PoSTWITA it postwita train
# Italian PoSTWITA it postwita test
# Latin ITTB la ittb test
# Latin ITTB la ittb dev
# Latin ITTB la ittb train
# Madi Jarawara jaa jarawara test
# Spanish PUD es pud test
# Buryat BDT bxr bdt test
# Buryat BDT bxr bdt train
# Italian ParlaMint it parlamint train
# Italian ParlaMint it parlamint test
# Kaapor TuDeT urb tudet test
# Korean PUD ko pud test
# Polish PUD pl pud test
# Latin Perseus la perseus train
# Latin Perseus la perseus test
# Icelandic GC is gc dev
# Icelandic GC is gc train
# Icelandic GC is gc test
# Estonian EDT et edt train
# Estonian EDT et edt test
# Estonian EDT et edt dev
# Croatian SET hr set train
# Croatian SET hr set dev
# Croatian SET hr set test
# Gothic PROIEL got proiel test
# Gothic PROIEL got proiel dev
# Gothic PROIEL got proiel train
# Old_French PROFITEROLE fro profiterole train
# Old_French PROFITEROLE fro profiterole dev
# Old_French PROFITEROLE fro profiterole test
# Turkish FrameNet tr framenet test
# Turkish FrameNet tr framenet train
# Turkish FrameNet tr framenet dev
# Latin LLCT la llct dev
# Latin LLCT la llct train
# Latin LLCT la llct test
# Swedish_Sign_Language SSLC swl sslc test
# Turkish Atis tr atis dev
# Turkish Atis tr atis train
# Turkish Atis tr atis test
# Swiss_German UZH gsw uzh test
# Middle_French PROFITEROLE frm profiterole test
# Assyrian AS aii as test
# Italian ISDT it isdt dev
# Italian ISDT it isdt train
# Italian ISDT it isdt test
# North_Sami Giella sme giella train
# North_Sami Giella sme giella test
# Norwegian Bokmaal no bokmaal dev
# Norwegian Bokmaal no bokmaal test
# Norwegian Bokmaal no bokmaal train
# French ParisStories fr parisstories train
# French ParisStories fr parisstories test
# French ParisStories fr parisstories dev
# Naija NSC pcm nsc test
# Naija NSC pcm nsc dev
# Naija NSC pcm nsc train
# English ESLSpok en eslspok dev
# English ESLSpok en eslspok test
# English ESLSpok en eslspok train
# German LIT de lit test
# Italian MarkIT it markit train
# Italian MarkIT it markit dev
# Italian MarkIT it markit test
# Latvian LVTB lv lvtb train
# Latvian LVTB lv lvtb dev
# Latvian LVTB lv lvtb test
# Chinese GSDSimp zh gsdsimp train
# Chinese GSDSimp zh gsdsimp test
# Chinese GSDSimp zh gsdsimp dev
# Irish Cadhan ga cadhan test
# Xibe XDT sjo xdt test
# Tagalog Ugnayan tl ugnayan test
# Bambara CRB bm crb test
# Lithuanian ALKSNIS lt alksnis dev
# Lithuanian ALKSNIS lt alksnis test
# Lithuanian ALKSNIS lt alksnis train
# Ancient_Greek PTNK grc ptnk train
# Ancient_Greek PTNK grc ptnk dev
# Ancient_Greek PTNK grc ptnk test
# Galician CTG gl ctg test
# Galician CTG gl ctg dev
# Galician CTG gl ctg train
# Haitian_Creole Autogramm ht autogramm test
# Chinese HK zh hk test
# Cebuano GJA ceb gja test
# Vietnamese VTB vi vtb test
# Vietnamese VTB vi vtb dev
# Vietnamese VTB vi vtb train
# Korean GSD ko gsd test
# Korean GSD ko gsd train
# Korean GSD ko gsd dev
# Amharic ATT am att test
# Greek GDT el gdt train
# Greek GDT el gdt test
# Greek GDT el gdt dev
# German HDT de hdt train
# German HDT de hdt dev
# German HDT de hdt test
# Spanish GSD es gsd test
# Spanish GSD es gsd train
# Spanish GSD es gsd dev
# Catalan AnCora ca ancora test
# Catalan AnCora ca ancora dev
# Catalan AnCora ca ancora train
# English PUD en pud test
# Russian Poetry ru poetry test
# Russian Poetry ru poetry train
# Russian Poetry ru poetry dev
# Veps VWT vep vwt test
# English EWT en ewt test
# English EWT en ewt dev
# English EWT en ewt train
# Soi AHA soj aha test
# Old_East_Slavic RNC orv rnc train
# Old_East_Slavic RNC orv rnc test
# Old_East_Slavic RNC orv rnc dev
# Swedish LinES sv lines dev
# Swedish LinES sv lines test
# Swedish LinES sv lines train
# Yupik SLI ess sli test
# Russian SynTagRus ru syntagrus dev
# Russian SynTagRus ru syntagrus test
# Russian SynTagRus ru syntagrus train
# Czech PDT cs pdt dev
# Czech PDT cs pdt train
# Czech PDT cs pdt test
# Beja NSC bej nsc test
# Italian VIT it vit test
# Italian VIT it vit dev
# Italian VIT it vit train
# Erzya JR myv jr train
# Erzya JR myv jr test
# Macedonian MTB mk mtb test
# Armenian BSUT hy bsut train
# Armenian BSUT hy bsut dev
# Armenian BSUT hy bsut test
# Bhojpuri BHTB bho bhtb test
# Polish LFG pl lfg dev
# Polish LFG pl lfg train
# Polish LFG pl lfg test
# Zaar Autogramm say autogramm test
# Umbrian IKUVINA xum ikuvina test
# Thai PUD th pud test
# Marathi UFAL mr ufal train
# Marathi UFAL mr ufal dev
# Marathi UFAL mr ufal test
# Basque BDT eu bdt test
# Basque BDT eu bdt dev
# Basque BDT eu bdt train
# Slovak SNK sk snk dev
# Slovak SNK sk snk train
# Slovak SNK sk snk test
# Javanese CSUI jv csui test
# Kiche IU quc iu test
# English GENTLE en gentle test
# Japanese GSDLUW ja gsdluw train
# Japanese GSDLUW ja gsdluw dev
# Japanese GSDLUW ja gsdluw test
# Russian Taiga ru taiga test
# Russian Taiga ru taiga dev
# Russian Taiga ru taiga train
# Guarani OldTuDeT gn oldtudet test
# Yoruba YTB yo ytb test
# Warlpiri UFAL wbp ufal test
# Low_Saxon LSDC nds lsdc test
# English Pronouns en pronouns test
# Finnish OOD fi ood test
# Tamil TTB ta ttb train
# Tamil TTB ta ttb dev
# Tamil TTB ta ttb test
# Georgian GLC ka glc test
# Spanish AnCora es ancora train
# Spanish AnCora es ancora test
# Spanish AnCora es ancora dev
# Maltese MUDT mt mudt test
# Maltese MUDT mt mudt train
# Maltese MUDT mt mudt dev
# Finnish TDT fi tdt train
# Finnish TDT fi tdt dev
# Finnish TDT fi tdt test
# French Rhapsodie fr rhapsodie dev
# French Rhapsodie fr rhapsodie train
# French Rhapsodie fr rhapsodie test
# Nheengatu CompLin yrl complin test
# Old_Irish DipSGG sga dipsgg test
# Indonesian CSUI id csui train
# Indonesian CSUI id csui test
# Ancient_Greek Perseus grc perseus dev
# Ancient_Greek Perseus grc perseus test
# Ancient_Greek Perseus grc perseus train
# Old_East_Slavic Birchbark orv birchbark dev
# Old_East_Slavic Birchbark orv birchbark test
# Old_East_Slavic Birchbark orv birchbark train
# Ancient_Hebrew PTNK hbo ptnk train
# Ancient_Hebrew PTNK hbo ptnk test
# Ancient_Hebrew PTNK hbo ptnk dev
# Tatar NMCTT tt nmctt test
# Icelandic IcePaHC is icepahc train
# Icelandic IcePaHC is icepahc test
# Icelandic IcePaHC is icepahc dev
# Mbya_Guarani Thomas gun thomas test
# Urdu UDTB ur udtb train
# Urdu UDTB ur udtb dev
# Urdu UDTB ur udtb test
# Romanian RRT ro rrt dev
# Romanian RRT ro rrt test
# Romanian RRT ro rrt train
# Tagalog TRG tl trg test
# Akkadian PISANDUB akk pisandub test
# Latin PROIEL la proiel train
# Latin PROIEL la proiel test
# Latin PROIEL la proiel dev
# Persian PerDT fa perdt test
# Persian PerDT fa perdt train
# Persian PerDT fa perdt dev
# Apurina UFPA apu ufpa test
# Sinhala STB si stb test
# Indonesian PUD id pud test
# French ParTUT fr partut train
# French ParTUT fr partut dev
# French ParTUT fr partut test
# Icelandic Modern is modern train
# Icelandic Modern is modern test
# Icelandic Modern is modern dev
# Hungarian Szeged hu szeged train
# Hungarian Szeged hu szeged test
# Hungarian Szeged hu szeged dev
# Hindi HDTB hi hdtb test
# Hindi HDTB hi hdtb train
# Hindi HDTB hi hdtb dev
# Classical_Chinese Kyoto lzh kyoto dev
# Classical_Chinese Kyoto lzh kyoto train
# Classical_Chinese Kyoto lzh kyoto test
# Komi_Permyak UH koi uh test
# Komi_Permyak UH koi uh train
# Chinese CFL zh cfl test
# Faroese FarPaHC fo farpahc dev
# Faroese FarPaHC fo farpahc test
# Faroese FarPaHC fo farpahc train
# Sanskrit Vedic sa vedic test
# Sanskrit Vedic sa vedic train
# Turkish IMST tr imst dev
# Turkish IMST tr imst test
# Turkish IMST tr imst train
# Portuguese Porttinari pt porttinari test
# Portuguese Porttinari pt porttinari train
# Portuguese Porttinari pt porttinari dev
# Lithuanian HSE lt hse train
# Lithuanian HSE lt hse dev
# Lithuanian HSE lt hse test
# Slovenian SSJ sl ssj test
# Slovenian SSJ sl ssj train
# Slovenian SSJ sl ssj dev
# Livvi KKPP olo kkpp test
# Livvi KKPP olo kkpp train
# Swedish Talbanken sv talbanken test
# Swedish Talbanken sv talbanken dev
# Swedish Talbanken sv talbanken train
# Arabic NYUAD ar nyuad train
# Arabic NYUAD ar nyuad dev
# Arabic NYUAD ar nyuad test
# English GUMReddit en gumreddit train
# English GUMReddit en gumreddit test
# English GUMReddit en gumreddit dev
# Italian ParTUT it partut train
# Italian ParTUT it partut test
# Italian ParTUT it partut dev
# Czech FicTree cs fictree train
# Czech FicTree cs fictree test
# Czech FicTree cs fictree dev
# Wolof WTB wo wtb test
# Wolof WTB wo wtb dev
# Wolof WTB wo wtb train
# Bulgarian BTB bg btb test
# Bulgarian BTB bg btb train
# Bulgarian BTB bg btb dev
# Russian PUD ru pud test
# Portuguese PUD pt pud test
# Romanian ArT ro art test
# Bororo BDT bor bdt test
# Akuntsu TuDeT aqz tudet test
# Portuguese PetroGold pt petrogold train
# Portuguese PetroGold pt petrogold test
# Portuguese PetroGold pt petrogold dev
# Makurap TuDeT mpu tudet test
# Turkish Penn tr penn train
# Turkish Penn tr penn dev
# Turkish Penn tr penn test
# Chinese Beginner zh beginner test
# Kangri KDTB xnr kdtb test
# Italian Valico it valico test
# Malayalam UFAL ml ufal test
# Japanese BCCWJ ja bccwj train
# Japanese BCCWJ ja bccwj test
# Japanese BCCWJ ja bccwj dev
# Bengali BRU bn bru test
# Italian TWITTIRO it twittiro test
# Italian TWITTIRO it twittiro train
# Italian TWITTIRO it twittiro dev
# Ancient_Greek PROIEL grc proiel dev
# Ancient_Greek PROIEL grc proiel train
# Ancient_Greek PROIEL grc proiel test
# Breton KEB br keb test
# Czech CAC cs cac train
# Czech CAC cs cac test
# Czech CAC cs cac dev
# Japanese GSD ja gsd train
# Japanese GSD ja gsd test
# Japanese GSD ja gsd dev
# Neapolitan RB nap rb test
# Telugu MTG te mtg train
# Telugu MTG te mtg test
# Telugu MTG te mtg dev
# Italian Old it old train
# Italian Old it old test
# Italian Old it old dev
# Korean Kaist ko kaist train
# Korean Kaist ko kaist dev
# Korean Kaist ko kaist test
# Cantonese HK yue hk test
# Turkish_German SAGT qtd sagt test
# Turkish_German SAGT qtd sagt dev
# Turkish_German SAGT qtd sagt train
# Teko TuDeT eme tudet test
# English GUM en gum dev
# English GUM en gum test
# English GUM en gum train
# Chinese PUD zh pud test
# Pomak Philotis qpm philotis dev
# Pomak Philotis qpm philotis train
# Pomak Philotis qpm philotis test
# Romanian Nonstandard ro nonstandard test
# Romanian Nonstandard ro nonstandard train
# Romanian Nonstandard ro nonstandard dev
# German GSD de gsd train
# German GSD de gsd dev
# German GSD de gsd test
# Old_Church_Slavonic PROIEL cu proiel dev
# Old_Church_Slavonic PROIEL cu proiel test
# Old_Church_Slavonic PROIEL cu proiel train
# Karelian KKPP krl kkpp test
# Maghrebi_Arabic_French Arabizi qaf arabizi dev
# Maghrebi_Arabic_French Arabizi qaf arabizi train
# Maghrebi_Arabic_French Arabizi qaf arabizi test
# Portuguese CINTIL pt cintil test
# Portuguese CINTIL pt cintil train
# Portuguese CINTIL pt cintil dev
# French PUD fr pud test
# Upper_Sorbian UFAL hsb ufal train
# Upper_Sorbian UFAL hsb ufal test
# Danish DDT da ddt train
# Danish DDT da ddt dev
# Danish DDT da ddt test
# Highland_Puebla_Nahuatl ITML azz itml test
# Icelandic PUD is pud test
# Galician TreeGal gl treegal test
# Galician TreeGal gl treegal train
# Hindi PUD hi pud test
# Japanese PUDLUW ja pudluw test
# South_Levantine_Arabic MADAR ajp madar test
# Komi_Zyrian Lattice kpv lattice train
# Komi_Zyrian Lattice kpv lattice test
# Western_Sierra_Puebla_Nahuatl ITML nhi itml test
# Sanskrit UFAL sa ufal test
# Tamil MWTT ta mwtt test
# Turkish PUD tr pud test
# Irish IDT ga idt test
# Irish IDT ga idt train
# Irish IDT ga idt dev
# Czech Poetry cs poetry test
# Faroese OFT fo oft test
# Nayini AHA nyq aha test
# Frisian_Dutch Fame qfn fame test
# Munduruku TuDeT myu tudet test
# Hittite HitTB hit hittb test
# Manx Cadhan gv cadhan test
# Manx Cadhan gv cadhan train
# Kyrgyz KTMU ky ktmu train
# Kyrgyz KTMU ky ktmu test
# Skolt_Sami Giellagas sms giellagas test
# Skolt_Sami Giellagas sms giellagas train
# Finnish PUD fi pud test
# Mbya_Guarani Dooley gun dooley test
# Persian Seraji fa seraji test
# Persian Seraji fa seraji dev
# Persian Seraji fa seraji train
# Ligurian GLT lij glt train
# Ligurian GLT lij glt test
# Afrikaans AfriBooms af afribooms dev
# Afrikaans AfriBooms af afribooms test
# Afrikaans AfriBooms af afribooms train
# Japanese PUD ja pud test
# Czech CLTT cs cltt train
# Czech CLTT cs cltt test
# Czech CLTT cs cltt dev
# French GSD fr gsd dev
# French GSD fr gsd train
# French GSD fr gsd test
# Karo TuDeT arr tudet test
# German PUD de pud test
# Irish TwittIrish ga twittirish test
# Irish TwittIrish ga twittirish dev
# Irish TwittIrish ga twittirish train
# Dutch Alpino nl alpino train
# Dutch Alpino nl alpino test
# Dutch Alpino nl alpino dev
# Swedish PUD sv pud test
# Chinese GSD zh gsd train
# Chinese GSD zh gsd test
# Chinese GSD zh gsd dev
# Old_Turkish Tonqq otk tonqq test
# Romanian SiMoNERo ro simonero dev
# Romanian SiMoNERo ro simonero train
# Romanian SiMoNERo ro simonero test
# Arabic PUD ar pud test
# Tupinamba TuDeT tpn tudet test
# Belarusian HSE be hse train
# Belarusian HSE be hse dev
# Belarusian HSE be hse test
# Coptic Scriptorium cop scriptorium train
# Coptic Scriptorium cop scriptorium dev
# Coptic Scriptorium cop scriptorium test
# Yakut YKTDT sah yktdt test
# French FQB fr fqb test
# Abaza ATB abq atb test
# Komi_Zyrian IKDP kpv ikdp test
# Serbian SET sr set train
# Serbian SET sr set dev
# Serbian SET sr set test
# Turkish Tourism tr tourism test
# Turkish Tourism tr tourism train
# Turkish Tourism tr tourism dev
# Estonian EWT et ewt test
# Estonian EWT et ewt dev
# Estonian EWT et ewt train
# Moksha JR mdf jr test
# Moksha JR mdf jr train
# Western_Armenian ArmTDP hyw armtdp test
# Western_Armenian ArmTDP hyw armtdp dev
# Western_Armenian ArmTDP hyw armtdp train
# Czech PUD cs pud test
# Old_Irish DipWBG sga dipwbg test
# Scottish_Gaelic ARCOSG gd arcosg dev
# Scottish_Gaelic ARCOSG gd arcosg train
# Scottish_Gaelic ARCOSG gd arcosg test
# Portuguese GSD pt gsd dev
# Portuguese GSD pt gsd train
# Portuguese GSD pt gsd test
# Chinese PatentChar zh patentchar test
# Russian GSD ru gsd test
# Russian GSD ru gsd train
# Russian GSD ru gsd dev
# Khunsari AHA kfm aha test
# Turkish BOUN tr boun test
# Turkish BOUN tr boun train
# Turkish BOUN tr boun dev
# Arabic PADT ar padt dev
# Arabic PADT ar padt train
# Arabic PADT ar padt test
# Hebrew HTB he htb dev
# Hebrew HTB he htb train
# Hebrew HTB he htb test
# Greek GUD el gud test
# Greek GUD el gud train
# English ParTUT en partut test
# English ParTUT en partut train
# English ParTUT en partut dev
# Uyghur UDT ug udt test
# Uyghur UDT ug udt train
# Uyghur UDT ug udt dev
# Latin UDante la udante train
# Latin UDante la udante dev
# Latin UDante la udante test
# Japanese BCCWJLUW ja bccwjluw train
# Japanese BCCWJLUW ja bccwjluw dev
# Japanese BCCWJLUW ja bccwjluw test
# Chukchi HSE ckt hse test
# Xavante XDT xav xdt test

# %%
_UD_DATASETS
# Out:
# {'akk': {'test': ['UD_Akkadian-RIAO/akk_riao-ud-test.conllu',
#    'UD_Akkadian-PISANDUB/akk_pisandub-ud-test.conllu']},
#  'hy': {'train': ['UD_Armenian-ArmTDP/hy_armtdp-ud-train.conllu',
#    'UD_Armenian-BSUT/hy_bsut-ud-train.conllu'],
#   'test': ['UD_Armenian-ArmTDP/hy_armtdp-ud-test.conllu',
#    'UD_Armenian-BSUT/hy_bsut-ud-test.conllu'],
#   'dev': ['UD_Armenian-ArmTDP/hy_armtdp-ud-dev.conllu',
#    'UD_Armenian-BSUT/hy_bsut-ud-dev.conllu']},
#  'cy': {'train': ['UD_Welsh-CCG/cy_ccg-ud-train.conllu'],
#   'dev': ['UD_Welsh-CCG/cy_ccg-ud-dev.conllu'],
#   'test': ['UD_Welsh-CCG/cy_ccg-ud-test.conllu']},
#  'aln': {'test': ['UD_Gheg-GPS/aln_gps-ud-test.conllu']},
#  'no': {'test': ['UD_Norwegian-Nynorsk/no_nynorsk-ud-test.conllu',
#    'UD_Norwegian-Bokmaal/no_bokmaal-ud-test.conllu'],
#   'dev': ['UD_Norwegian-Nynorsk/no_nynorsk-ud-dev.conllu',
#    'UD_Norwegian-Bokmaal/no_bokmaal-ud-dev.conllu'],
#   'train': ['UD_Norwegian-Nynorsk/no_nynorsk-ud-train.conllu',
#    'UD_Norwegian-Bokmaal/no_bokmaal-ud-train.conllu']},
#  'orv': {'test': ['UD_Old_East_Slavic-TOROT/orv_torot-ud-test.conllu',
#    'UD_Old_East_Slavic-Ruthenian/orv_ruthenian-ud-test.conllu',
#    'UD_Old_East_Slavic-RNC/orv_rnc-ud-test.conllu',
#    'UD_Old_East_Slavic-Birchbark/orv_birchbark-ud-test.conllu'],
#   'train': ['UD_Old_East_Slavic-TOROT/orv_torot-ud-train.conllu',
#    'UD_Old_East_Slavic-Ruthenian/orv_ruthenian-ud-train.conllu',
#    'UD_Old_East_Slavic-RNC/orv_rnc-ud-train.conllu',
#    'UD_Old_East_Slavic-Birchbark/orv_birchbark-ud-train.conllu'],
#   'dev': ['UD_Old_East_Slavic-TOROT/orv_torot-ud-dev.conllu',
#    'UD_Old_East_Slavic-Ruthenian/orv_ruthenian-ud-dev.conllu',
#    'UD_Old_East_Slavic-RNC/orv_rnc-ud-dev.conllu',
#    'UD_Old_East_Slavic-Birchbark/orv_birchbark-ud-dev.conllu']},
#  'en': {'train': ['UD_English-LinES/en_lines-ud-train.conllu',
#    'UD_English-Atis/en_atis-ud-train.conllu',
#    'UD_English-ESLSpok/en_eslspok-ud-train.conllu',
#    'UD_English-EWT/en_ewt-ud-train.conllu',
#    'UD_English-GUMReddit/en_gumreddit-ud-train.conllu',
#    'UD_English-GUM/en_gum-ud-train.conllu',
#    'UD_English-ParTUT/en_partut-ud-train.conllu'],
#   'dev': ['UD_English-LinES/en_lines-ud-dev.conllu',
#    'UD_English-Atis/en_atis-ud-dev.conllu',
#    'UD_English-ESLSpok/en_eslspok-ud-dev.conllu',
#    'UD_English-EWT/en_ewt-ud-dev.conllu',
#    'UD_English-GUMReddit/en_gumreddit-ud-dev.conllu',
#    'UD_English-GUM/en_gum-ud-dev.conllu',
#    'UD_English-ParTUT/en_partut-ud-dev.conllu'],
#   'test': ['UD_English-LinES/en_lines-ud-test.conllu',
#    'UD_English-Atis/en_atis-ud-test.conllu',
#    'UD_English-ESLSpok/en_eslspok-ud-test.conllu',
#    'UD_English-PUD/en_pud-ud-test.conllu',
#    'UD_English-EWT/en_ewt-ud-test.conllu',
#    'UD_English-GENTLE/en_gentle-ud-test.conllu',
#    'UD_English-Pronouns/en_pronouns-ud-test.conllu',
#    'UD_English-GUMReddit/en_gumreddit-ud-test.conllu',
#    'UD_English-GUM/en_gum-ud-test.conllu',
#    'UD_English-ParTUT/en_partut-ud-test.conllu']},
#  'sq': {'test': ['UD_Albanian-TSA/sq_tsa-ud-test.conllu']},
#  'fr': {'dev': ['UD_French-Sequoia/fr_sequoia-ud-dev.conllu',
#    'UD_French-ParisStories/fr_parisstories-ud-dev.conllu',
#    'UD_French-Rhapsodie/fr_rhapsodie-ud-dev.conllu',
#    'UD_French-ParTUT/fr_partut-ud-dev.conllu',
#    'UD_French-GSD/fr_gsd-ud-dev.conllu'],
#   'train': ['UD_French-Sequoia/fr_sequoia-ud-train.conllu',
#    'UD_French-ParisStories/fr_parisstories-ud-train.conllu',
#    'UD_French-Rhapsodie/fr_rhapsodie-ud-train.conllu',
#    'UD_French-ParTUT/fr_partut-ud-train.conllu',
#    'UD_French-GSD/fr_gsd-ud-train.conllu'],
#   'test': ['UD_French-Sequoia/fr_sequoia-ud-test.conllu',
#    'UD_French-ParisStories/fr_parisstories-ud-test.conllu',
#    'UD_French-Rhapsodie/fr_rhapsodie-ud-test.conllu',
#    'UD_French-ParTUT/fr_partut-ud-test.conllu',
#    'UD_French-PUD/fr_pud-ud-test.conllu',
#    'UD_French-GSD/fr_gsd-ud-test.conllu',
#    'UD_French-FQB/fr_fqb-ud-test.conllu']},
#  'xcl': {'test': ['UD_Classical_Armenian-CAVaL/xcl_caval-ud-test.conllu']},
#  'sl': {'test': ['UD_Slovenian-SST/sl_sst-ud-test.conllu',
#    'UD_Slovenian-SSJ/sl_ssj-ud-test.conllu'],
#   'train': ['UD_Slovenian-SST/sl_sst-ud-train.conllu',
#    'UD_Slovenian-SSJ/sl_ssj-ud-train.conllu'],
#   'dev': ['UD_Slovenian-SSJ/sl_ssj-ud-dev.conllu']},
#  'he': {'test': ['UD_Hebrew-IAHLTwiki/he_iahltwiki-ud-test.conllu',
#    'UD_Hebrew-HTB/he_htb-ud-test.conllu'],
#   'dev': ['UD_Hebrew-IAHLTwiki/he_iahltwiki-ud-dev.conllu',
#    'UD_Hebrew-HTB/he_htb-ud-dev.conllu'],
#   'train': ['UD_Hebrew-IAHLTwiki/he_iahltwiki-ud-train.conllu',
#    'UD_Hebrew-HTB/he_htb-ud-train.conllu']},
#  'gub': {'test': ['UD_Guajajara-TuDeT/gub_tudet-ud-test.conllu']},
#  'kmr': {'test': ['UD_Kurmanji-MG/kmr_mg-ud-test.conllu'],
#   'train': ['UD_Kurmanji-MG/kmr_mg-ud-train.conllu']},
#  'it': {'test': ['UD_Italian-PUD/it_pud-ud-test.conllu',
#    'UD_Italian-PoSTWITA/it_postwita-ud-test.conllu',
#    'UD_Italian-ParlaMint/it_parlamint-ud-test.conllu',
#    'UD_Italian-ISDT/it_isdt-ud-test.conllu',
#    'UD_Italian-MarkIT/it_markit-ud-test.conllu',
#    'UD_Italian-VIT/it_vit-ud-test.conllu',
#    'UD_Italian-ParTUT/it_partut-ud-test.conllu',
#    'UD_Italian-Valico/it_valico-ud-test.conllu',
#    'UD_Italian-TWITTIRO/it_twittiro-ud-test.conllu',
#    'UD_Italian-Old/it_old-ud-test.conllu'],
#   'dev': ['UD_Italian-PoSTWITA/it_postwita-ud-dev.conllu',
#    'UD_Italian-ISDT/it_isdt-ud-dev.conllu',
#    'UD_Italian-MarkIT/it_markit-ud-dev.conllu',
#    'UD_Italian-VIT/it_vit-ud-dev.conllu',
#    'UD_Italian-ParTUT/it_partut-ud-dev.conllu',
#    'UD_Italian-TWITTIRO/it_twittiro-ud-dev.conllu',
#    'UD_Italian-Old/it_old-ud-dev.conllu'],
#   'train': ['UD_Italian-PoSTWITA/it_postwita-ud-train.conllu',
#    'UD_Italian-ParlaMint/it_parlamint-ud-train.conllu',
#    'UD_Italian-ISDT/it_isdt-ud-train.conllu',
#    'UD_Italian-MarkIT/it_markit-ud-train.conllu',
#    'UD_Italian-VIT/it_vit-ud-train.conllu',
#    'UD_Italian-ParTUT/it_partut-ud-train.conllu',
#    'UD_Italian-TWITTIRO/it_twittiro-ud-train.conllu',
#    'UD_Italian-Old/it_old-ud-train.conllu']},
#  'tr': {'test': ['UD_Turkish-GB/tr_gb-ud-test.conllu',
#    'UD_Turkish-Kenet/tr_kenet-ud-test.conllu',
#    'UD_Turkish-FrameNet/tr_framenet-ud-test.conllu',
#    'UD_Turkish-Atis/tr_atis-ud-test.conllu',
#    'UD_Turkish-IMST/tr_imst-ud-test.conllu',
#    'UD_Turkish-Penn/tr_penn-ud-test.conllu',
#    'UD_Turkish-PUD/tr_pud-ud-test.conllu',
#    'UD_Turkish-Tourism/tr_tourism-ud-test.conllu',
#    'UD_Turkish-BOUN/tr_boun-ud-test.conllu'],
#   'dev': ['UD_Turkish-Kenet/tr_kenet-ud-dev.conllu',
#    'UD_Turkish-FrameNet/tr_framenet-ud-dev.conllu',
#    'UD_Turkish-Atis/tr_atis-ud-dev.conllu',
#    'UD_Turkish-IMST/tr_imst-ud-dev.conllu',
#    'UD_Turkish-Penn/tr_penn-ud-dev.conllu',
#    'UD_Turkish-Tourism/tr_tourism-ud-dev.conllu',
#    'UD_Turkish-BOUN/tr_boun-ud-dev.conllu'],
#   'train': ['UD_Turkish-Kenet/tr_kenet-ud-train.conllu',
#    'UD_Turkish-FrameNet/tr_framenet-ud-train.conllu',
#    'UD_Turkish-Atis/tr_atis-ud-train.conllu',
#    'UD_Turkish-IMST/tr_imst-ud-train.conllu',
#    'UD_Turkish-Penn/tr_penn-ud-train.conllu',
#    'UD_Turkish-Tourism/tr_tourism-ud-train.conllu',
#    'UD_Turkish-BOUN/tr_boun-ud-train.conllu']},
#  'fi': {'test': ['UD_Finnish-FTB/fi_ftb-ud-test.conllu',
#    'UD_Finnish-OOD/fi_ood-ud-test.conllu',
#    'UD_Finnish-TDT/fi_tdt-ud-test.conllu',
#    'UD_Finnish-PUD/fi_pud-ud-test.conllu'],
#   'dev': ['UD_Finnish-FTB/fi_ftb-ud-dev.conllu',
#    'UD_Finnish-TDT/fi_tdt-ud-dev.conllu'],
#   'train': ['UD_Finnish-FTB/fi_ftb-ud-train.conllu',
#    'UD_Finnish-TDT/fi_tdt-ud-train.conllu']},
#  'id': {'test': ['UD_Indonesian-GSD/id_gsd-ud-test.conllu',
#    'UD_Indonesian-CSUI/id_csui-ud-test.conllu',
#    'UD_Indonesian-PUD/id_pud-ud-test.conllu'],
#   'train': ['UD_Indonesian-GSD/id_gsd-ud-train.conllu',
#    'UD_Indonesian-CSUI/id_csui-ud-train.conllu'],
#   'dev': ['UD_Indonesian-GSD/id_gsd-ud-dev.conllu']},
#  'uk': {'test': ['UD_Ukrainian-IU/uk_iu-ud-test.conllu'],
#   'dev': ['UD_Ukrainian-IU/uk_iu-ud-dev.conllu'],
#   'train': ['UD_Ukrainian-IU/uk_iu-ud-train.conllu']},
#  'nl': {'dev': ['UD_Dutch-LassySmall/nl_lassysmall-ud-dev.conllu',
#    'UD_Dutch-Alpino/nl_alpino-ud-dev.conllu'],
#   'train': ['UD_Dutch-LassySmall/nl_lassysmall-ud-train.conllu',
#    'UD_Dutch-Alpino/nl_alpino-ud-train.conllu'],
#   'test': ['UD_Dutch-LassySmall/nl_lassysmall-ud-test.conllu',
#    'UD_Dutch-Alpino/nl_alpino-ud-test.conllu']},
#  'pl': {'test': ['UD_Polish-PDB/pl_pdb-ud-test.conllu',
#    'UD_Polish-PUD/pl_pud-ud-test.conllu',
#    'UD_Polish-LFG/pl_lfg-ud-test.conllu'],
#   'train': ['UD_Polish-PDB/pl_pdb-ud-train.conllu',
#    'UD_Polish-LFG/pl_lfg-ud-train.conllu'],
#   'dev': ['UD_Polish-PDB/pl_pdb-ud-dev.conllu',
#    'UD_Polish-LFG/pl_lfg-ud-dev.conllu']},
#  'pt': {'test': ['UD_Portuguese-Bosque/pt_bosque-ud-test.conllu',
#    'UD_Portuguese-Porttinari/pt_porttinari-ud-test.conllu',
#    'UD_Portuguese-PUD/pt_pud-ud-test.conllu',
#    'UD_Portuguese-PetroGold/pt_petrogold-ud-test.conllu',
#    'UD_Portuguese-CINTIL/pt_cintil-ud-test.conllu',
#    'UD_Portuguese-GSD/pt_gsd-ud-test.conllu'],
#   'dev': ['UD_Portuguese-Bosque/pt_bosque-ud-dev.conllu',
#    'UD_Portuguese-Porttinari/pt_porttinari-ud-dev.conllu',
#    'UD_Portuguese-PetroGold/pt_petrogold-ud-dev.conllu',
#    'UD_Portuguese-CINTIL/pt_cintil-ud-dev.conllu',
#    'UD_Portuguese-GSD/pt_gsd-ud-dev.conllu'],
#   'train': ['UD_Portuguese-Bosque/pt_bosque-ud-train.conllu',
#    'UD_Portuguese-Porttinari/pt_porttinari-ud-train.conllu',
#    'UD_Portuguese-PetroGold/pt_petrogold-ud-train.conllu',
#    'UD_Portuguese-CINTIL/pt_cintil-ud-train.conllu',
#    'UD_Portuguese-GSD/pt_gsd-ud-train.conllu']},
#  'kk': {'test': ['UD_Kazakh-KTB/kk_ktb-ud-test.conllu'],
#   'train': ['UD_Kazakh-KTB/kk_ktb-ud-train.conllu']},
#  'la': {'test': ['UD_Latin-ITTB/la_ittb-ud-test.conllu',
#    'UD_Latin-Perseus/la_perseus-ud-test.conllu',
#    'UD_Latin-LLCT/la_llct-ud-test.conllu',
#    'UD_Latin-PROIEL/la_proiel-ud-test.conllu',
#    'UD_Latin-UDante/la_udante-ud-test.conllu'],
#   'dev': ['UD_Latin-ITTB/la_ittb-ud-dev.conllu',
#    'UD_Latin-LLCT/la_llct-ud-dev.conllu',
#    'UD_Latin-PROIEL/la_proiel-ud-dev.conllu',
#    'UD_Latin-UDante/la_udante-ud-dev.conllu'],
#   'train': ['UD_Latin-ITTB/la_ittb-ud-train.conllu',
#    'UD_Latin-Perseus/la_perseus-ud-train.conllu',
#    'UD_Latin-LLCT/la_llct-ud-train.conllu',
#    'UD_Latin-PROIEL/la_proiel-ud-train.conllu',
#    'UD_Latin-UDante/la_udante-ud-train.conllu']},
#  'jaa': {'test': ['UD_Madi-Jarawara/jaa_jarawara-ud-test.conllu']},
#  'es': {'test': ['UD_Spanish-PUD/es_pud-ud-test.conllu',
#    'UD_Spanish-GSD/es_gsd-ud-test.conllu',
#    'UD_Spanish-AnCora/es_ancora-ud-test.conllu'],
#   'train': ['UD_Spanish-GSD/es_gsd-ud-train.conllu',
#    'UD_Spanish-AnCora/es_ancora-ud-train.conllu'],
#   'dev': ['UD_Spanish-GSD/es_gsd-ud-dev.conllu',
#    'UD_Spanish-AnCora/es_ancora-ud-dev.conllu']},
#  'bxr': {'test': ['UD_Buryat-BDT/bxr_bdt-ud-test.conllu'],
#   'train': ['UD_Buryat-BDT/bxr_bdt-ud-train.conllu']},
#  'urb': {'test': ['UD_Kaapor-TuDeT/urb_tudet-ud-test.conllu']},
#  'ko': {'test': ['UD_Korean-PUD/ko_pud-ud-test.conllu',
#    'UD_Korean-GSD/ko_gsd-ud-test.conllu',
#    'UD_Korean-Kaist/ko_kaist-ud-test.conllu'],
#   'train': ['UD_Korean-GSD/ko_gsd-ud-train.conllu',
#    'UD_Korean-Kaist/ko_kaist-ud-train.conllu'],
#   'dev': ['UD_Korean-GSD/ko_gsd-ud-dev.conllu',
#    'UD_Korean-Kaist/ko_kaist-ud-dev.conllu']},
#  'is': {'dev': ['UD_Icelandic-GC/is_gc-ud-dev.conllu',
#    'UD_Icelandic-IcePaHC/is_icepahc-ud-dev.conllu',
#    'UD_Icelandic-Modern/is_modern-ud-dev.conllu'],
#   'train': ['UD_Icelandic-GC/is_gc-ud-train.conllu',
#    'UD_Icelandic-IcePaHC/is_icepahc-ud-train.conllu',
#    'UD_Icelandic-Modern/is_modern-ud-train.conllu'],
#   'test': ['UD_Icelandic-GC/is_gc-ud-test.conllu',
#    'UD_Icelandic-IcePaHC/is_icepahc-ud-test.conllu',
#    'UD_Icelandic-Modern/is_modern-ud-test.conllu',
#    'UD_Icelandic-PUD/is_pud-ud-test.conllu']},
#  'et': {'train': ['UD_Estonian-EDT/et_edt-ud-train.conllu',
#    'UD_Estonian-EWT/et_ewt-ud-train.conllu'],
#   'test': ['UD_Estonian-EDT/et_edt-ud-test.conllu',
#    'UD_Estonian-EWT/et_ewt-ud-test.conllu'],
#   'dev': ['UD_Estonian-EDT/et_edt-ud-dev.conllu',
#    'UD_Estonian-EWT/et_ewt-ud-dev.conllu']},
#  'hr': {'train': ['UD_Croatian-SET/hr_set-ud-train.conllu'],
#   'dev': ['UD_Croatian-SET/hr_set-ud-dev.conllu'],
#   'test': ['UD_Croatian-SET/hr_set-ud-test.conllu']},
#  'got': {'test': ['UD_Gothic-PROIEL/got_proiel-ud-test.conllu'],
#   'dev': ['UD_Gothic-PROIEL/got_proiel-ud-dev.conllu'],
#   'train': ['UD_Gothic-PROIEL/got_proiel-ud-train.conllu']},
#  'fro': {'train': ['UD_Old_French-PROFITEROLE/fro_profiterole-ud-train.conllu'],
#   'dev': ['UD_Old_French-PROFITEROLE/fro_profiterole-ud-dev.conllu'],
#   'test': ['UD_Old_French-PROFITEROLE/fro_profiterole-ud-test.conllu']},
#  'swl': {'test': ['UD_Swedish_Sign_Language-SSLC/swl_sslc-ud-test.conllu']},
#  'gsw': {'test': ['UD_Swiss_German-UZH/gsw_uzh-ud-test.conllu']},
#  'frm': {'test': ['UD_Middle_French-PROFITEROLE/frm_profiterole-ud-test.conllu']},
#  'aii': {'test': ['UD_Assyrian-AS/aii_as-ud-test.conllu']},
#  'sme': {'train': ['UD_North_Sami-Giella/sme_giella-ud-train.conllu'],
#   'test': ['UD_North_Sami-Giella/sme_giella-ud-test.conllu']},
#  'pcm': {'test': ['UD_Naija-NSC/pcm_nsc-ud-test.conllu'],
#   'dev': ['UD_Naija-NSC/pcm_nsc-ud-dev.conllu'],
#   'train': ['UD_Naija-NSC/pcm_nsc-ud-train.conllu']},
#  'de': {'test': ['UD_German-LIT/de_lit-ud-test.conllu',
#    'UD_German-HDT/de_hdt-ud-test.conllu',
#    'UD_German-GSD/de_gsd-ud-test.conllu',
#    'UD_German-PUD/de_pud-ud-test.conllu'],
#   'train': ['UD_German-HDT/de_hdt-ud-train.conllu',
#    'UD_German-GSD/de_gsd-ud-train.conllu'],
#   'dev': ['UD_German-HDT/de_hdt-ud-dev.conllu',
#    'UD_German-GSD/de_gsd-ud-dev.conllu']},
#  'lv': {'train': ['UD_Latvian-LVTB/lv_lvtb-ud-train.conllu'],
#   'dev': ['UD_Latvian-LVTB/lv_lvtb-ud-dev.conllu'],
#   'test': ['UD_Latvian-LVTB/lv_lvtb-ud-test.conllu']},
#  'zh': {'train': ['UD_Chinese-GSDSimp/zh_gsdsimp-ud-train.conllu',
#    'UD_Chinese-GSD/zh_gsd-ud-train.conllu'],
#   'test': ['UD_Chinese-GSDSimp/zh_gsdsimp-ud-test.conllu',
#    'UD_Chinese-HK/zh_hk-ud-test.conllu',
#    'UD_Chinese-CFL/zh_cfl-ud-test.conllu',
#    'UD_Chinese-Beginner/zh_beginner-ud-test.conllu',
#    'UD_Chinese-PUD/zh_pud-ud-test.conllu',
#    'UD_Chinese-GSD/zh_gsd-ud-test.conllu',
#    'UD_Chinese-PatentChar/zh_patentchar-ud-test.conllu'],
#   'dev': ['UD_Chinese-GSDSimp/zh_gsdsimp-ud-dev.conllu',
#    'UD_Chinese-GSD/zh_gsd-ud-dev.conllu']},
#  'ga': {'test': ['UD_Irish-Cadhan/ga_cadhan-ud-test.conllu',
#    'UD_Irish-IDT/ga_idt-ud-test.conllu',
#    'UD_Irish-TwittIrish/ga_twittirish-ud-test.conllu'],
#   'train': ['UD_Irish-IDT/ga_idt-ud-train.conllu',
#    'UD_Irish-TwittIrish/ga_twittirish-ud-train.conllu'],
#   'dev': ['UD_Irish-IDT/ga_idt-ud-dev.conllu',
#    'UD_Irish-TwittIrish/ga_twittirish-ud-dev.conllu']},
#  'sjo': {'test': ['UD_Xibe-XDT/sjo_xdt-ud-test.conllu']},
#  'tl': {'test': ['UD_Tagalog-Ugnayan/tl_ugnayan-ud-test.conllu',
#    'UD_Tagalog-TRG/tl_trg-ud-test.conllu']},
#  'bm': {'test': ['UD_Bambara-CRB/bm_crb-ud-test.conllu']},
#  'lt': {'dev': ['UD_Lithuanian-ALKSNIS/lt_alksnis-ud-dev.conllu',
#    'UD_Lithuanian-HSE/lt_hse-ud-dev.conllu'],
#   'test': ['UD_Lithuanian-ALKSNIS/lt_alksnis-ud-test.conllu',
#    'UD_Lithuanian-HSE/lt_hse-ud-test.conllu'],
#   'train': ['UD_Lithuanian-ALKSNIS/lt_alksnis-ud-train.conllu',
#    'UD_Lithuanian-HSE/lt_hse-ud-train.conllu']},
#  'grc': {'train': ['UD_Ancient_Greek-PTNK/grc_ptnk-ud-train.conllu',
#    'UD_Ancient_Greek-Perseus/grc_perseus-ud-train.conllu',
#    'UD_Ancient_Greek-PROIEL/grc_proiel-ud-train.conllu'],
#   'dev': ['UD_Ancient_Greek-PTNK/grc_ptnk-ud-dev.conllu',
#    'UD_Ancient_Greek-Perseus/grc_perseus-ud-dev.conllu',
#    'UD_Ancient_Greek-PROIEL/grc_proiel-ud-dev.conllu'],
#   'test': ['UD_Ancient_Greek-PTNK/grc_ptnk-ud-test.conllu',
#    'UD_Ancient_Greek-Perseus/grc_perseus-ud-test.conllu',
#    'UD_Ancient_Greek-PROIEL/grc_proiel-ud-test.conllu']},
#  'gl': {'test': ['UD_Galician-CTG/gl_ctg-ud-test.conllu',
#    'UD_Galician-TreeGal/gl_treegal-ud-test.conllu'],
#   'dev': ['UD_Galician-CTG/gl_ctg-ud-dev.conllu'],
#   'train': ['UD_Galician-CTG/gl_ctg-ud-train.conllu',
#    'UD_Galician-TreeGal/gl_treegal-ud-train.conllu']},
#  'ht': {'test': ['UD_Haitian_Creole-Autogramm/ht_autogramm-ud-test.conllu']},
#  'ceb': {'test': ['UD_Cebuano-GJA/ceb_gja-ud-test.conllu']},
#  'vi': {'test': ['UD_Vietnamese-VTB/vi_vtb-ud-test.conllu'],
#   'dev': ['UD_Vietnamese-VTB/vi_vtb-ud-dev.conllu'],
#   'train': ['UD_Vietnamese-VTB/vi_vtb-ud-train.conllu']},
#  'am': {'test': ['UD_Amharic-ATT/am_att-ud-test.conllu']},
#  'el': {'train': ['UD_Greek-GDT/el_gdt-ud-train.conllu',
#    'UD_Greek-GUD/el_gud-ud-train.conllu'],
#   'test': ['UD_Greek-GDT/el_gdt-ud-test.conllu',
#    'UD_Greek-GUD/el_gud-ud-test.conllu'],
#   'dev': ['UD_Greek-GDT/el_gdt-ud-dev.conllu']},
#  'ca': {'test': ['UD_Catalan-AnCora/ca_ancora-ud-test.conllu'],
#   'dev': ['UD_Catalan-AnCora/ca_ancora-ud-dev.conllu'],
#   'train': ['UD_Catalan-AnCora/ca_ancora-ud-train.conllu']},
#  'ru': {'test': ['UD_Russian-Poetry/ru_poetry-ud-test.conllu',
#    'UD_Russian-SynTagRus/ru_syntagrus-ud-test.conllu',
#    'UD_Russian-Taiga/ru_taiga-ud-test.conllu',
#    'UD_Russian-PUD/ru_pud-ud-test.conllu',
#    'UD_Russian-GSD/ru_gsd-ud-test.conllu'],
#   'train': ['UD_Russian-Poetry/ru_poetry-ud-train.conllu',
#    'UD_Russian-SynTagRus/ru_syntagrus-ud-train.conllu',
#    'UD_Russian-Taiga/ru_taiga-ud-train.conllu',
#    'UD_Russian-GSD/ru_gsd-ud-train.conllu'],
#   'dev': ['UD_Russian-Poetry/ru_poetry-ud-dev.conllu',
#    'UD_Russian-SynTagRus/ru_syntagrus-ud-dev.conllu',
#    'UD_Russian-Taiga/ru_taiga-ud-dev.conllu',
#    'UD_Russian-GSD/ru_gsd-ud-dev.conllu']},
#  'vep': {'test': ['UD_Veps-VWT/vep_vwt-ud-test.conllu']},
#  'soj': {'test': ['UD_Soi-AHA/soj_aha-ud-test.conllu']},
#  'sv': {'dev': ['UD_Swedish-LinES/sv_lines-ud-dev.conllu',
#    'UD_Swedish-Talbanken/sv_talbanken-ud-dev.conllu'],
#   'test': ['UD_Swedish-LinES/sv_lines-ud-test.conllu',
#    'UD_Swedish-Talbanken/sv_talbanken-ud-test.conllu',
#    'UD_Swedish-PUD/sv_pud-ud-test.conllu'],
#   'train': ['UD_Swedish-LinES/sv_lines-ud-train.conllu',
#    'UD_Swedish-Talbanken/sv_talbanken-ud-train.conllu']},
#  'ess': {'test': ['UD_Yupik-SLI/ess_sli-ud-test.conllu']},
#  'cs': {'dev': ['UD_Czech-PDT/cs_pdt-ud-dev.conllu',
#    'UD_Czech-FicTree/cs_fictree-ud-dev.conllu',
#    'UD_Czech-CAC/cs_cac-ud-dev.conllu',
#    'UD_Czech-CLTT/cs_cltt-ud-dev.conllu'],
#   'train': ['UD_Czech-PDT/cs_pdt-ud-train.conllu',
#    'UD_Czech-FicTree/cs_fictree-ud-train.conllu',
#    'UD_Czech-CAC/cs_cac-ud-train.conllu',
#    'UD_Czech-CLTT/cs_cltt-ud-train.conllu'],
#   'test': ['UD_Czech-PDT/cs_pdt-ud-test.conllu',
#    'UD_Czech-FicTree/cs_fictree-ud-test.conllu',
#    'UD_Czech-CAC/cs_cac-ud-test.conllu',
#    'UD_Czech-Poetry/cs_poetry-ud-test.conllu',
#    'UD_Czech-CLTT/cs_cltt-ud-test.conllu',
#    'UD_Czech-PUD/cs_pud-ud-test.conllu']},
#  'bej': {'test': ['UD_Beja-NSC/bej_nsc-ud-test.conllu']},
#  'myv': {'train': ['UD_Erzya-JR/myv_jr-ud-train.conllu'],
#   'test': ['UD_Erzya-JR/myv_jr-ud-test.conllu']},
#  'mk': {'test': ['UD_Macedonian-MTB/mk_mtb-ud-test.conllu']},
#  'bho': {'test': ['UD_Bhojpuri-BHTB/bho_bhtb-ud-test.conllu']},
#  'say': {'test': ['UD_Zaar-Autogramm/say_autogramm-ud-test.conllu']},
#  'xum': {'test': ['UD_Umbrian-IKUVINA/xum_ikuvina-ud-test.conllu']},
#  'th': {'test': ['UD_Thai-PUD/th_pud-ud-test.conllu']},
#  'mr': {'train': ['UD_Marathi-UFAL/mr_ufal-ud-train.conllu'],
#   'dev': ['UD_Marathi-UFAL/mr_ufal-ud-dev.conllu'],
#   'test': ['UD_Marathi-UFAL/mr_ufal-ud-test.conllu']},
#  'eu': {'test': ['UD_Basque-BDT/eu_bdt-ud-test.conllu'],
#   'dev': ['UD_Basque-BDT/eu_bdt-ud-dev.conllu'],
#   'train': ['UD_Basque-BDT/eu_bdt-ud-train.conllu']},
#  'sk': {'dev': ['UD_Slovak-SNK/sk_snk-ud-dev.conllu'],
#   'train': ['UD_Slovak-SNK/sk_snk-ud-train.conllu'],
#   'test': ['UD_Slovak-SNK/sk_snk-ud-test.conllu']},
#  'jv': {'test': ['UD_Javanese-CSUI/jv_csui-ud-test.conllu']},
#  'quc': {'test': ['UD_Kiche-IU/quc_iu-ud-test.conllu']},
#  'ja': {'train': ['UD_Japanese-GSDLUW/ja_gsdluw-ud-train.conllu',
#    'UD_Japanese-BCCWJ/ja_bccwj-ud-train.conllu',
#    'UD_Japanese-GSD/ja_gsd-ud-train.conllu',
#    'UD_Japanese-BCCWJLUW/ja_bccwjluw-ud-train.conllu'],
#   'dev': ['UD_Japanese-GSDLUW/ja_gsdluw-ud-dev.conllu',
#    'UD_Japanese-BCCWJ/ja_bccwj-ud-dev.conllu',
#    'UD_Japanese-GSD/ja_gsd-ud-dev.conllu',
#    'UD_Japanese-BCCWJLUW/ja_bccwjluw-ud-dev.conllu'],
#   'test': ['UD_Japanese-GSDLUW/ja_gsdluw-ud-test.conllu',
#    'UD_Japanese-BCCWJ/ja_bccwj-ud-test.conllu',
#    'UD_Japanese-GSD/ja_gsd-ud-test.conllu',
#    'UD_Japanese-PUDLUW/ja_pudluw-ud-test.conllu',
#    'UD_Japanese-PUD/ja_pud-ud-test.conllu',
#    'UD_Japanese-BCCWJLUW/ja_bccwjluw-ud-test.conllu']},
#  'gn': {'test': ['UD_Guarani-OldTuDeT/gn_oldtudet-ud-test.conllu']},
#  'yo': {'test': ['UD_Yoruba-YTB/yo_ytb-ud-test.conllu']},
#  'wbp': {'test': ['UD_Warlpiri-UFAL/wbp_ufal-ud-test.conllu']},
#  'nds': {'test': ['UD_Low_Saxon-LSDC/nds_lsdc-ud-test.conllu']},
#  'ta': {'train': ['UD_Tamil-TTB/ta_ttb-ud-train.conllu'],
#   'dev': ['UD_Tamil-TTB/ta_ttb-ud-dev.conllu'],
#   'test': ['UD_Tamil-TTB/ta_ttb-ud-test.conllu',
#    'UD_Tamil-MWTT/ta_mwtt-ud-test.conllu']},
#  'ka': {'test': ['UD_Georgian-GLC/ka_glc-ud-test.conllu']},
#  'mt': {'test': ['UD_Maltese-MUDT/mt_mudt-ud-test.conllu'],
#   'train': ['UD_Maltese-MUDT/mt_mudt-ud-train.conllu'],
#   'dev': ['UD_Maltese-MUDT/mt_mudt-ud-dev.conllu']},
#  'yrl': {'test': ['UD_Nheengatu-CompLin/yrl_complin-ud-test.conllu']},
#  'sga': {'test': ['UD_Old_Irish-DipSGG/sga_dipsgg-ud-test.conllu',
#    'UD_Old_Irish-DipWBG/sga_dipwbg-ud-test.conllu']},
#  'hbo': {'train': ['UD_Ancient_Hebrew-PTNK/hbo_ptnk-ud-train.conllu'],
#   'test': ['UD_Ancient_Hebrew-PTNK/hbo_ptnk-ud-test.conllu'],
#   'dev': ['UD_Ancient_Hebrew-PTNK/hbo_ptnk-ud-dev.conllu']},
#  'tt': {'test': ['UD_Tatar-NMCTT/tt_nmctt-ud-test.conllu']},
#  'gun': {'test': ['UD_Mbya_Guarani-Thomas/gun_thomas-ud-test.conllu',
#    'UD_Mbya_Guarani-Dooley/gun_dooley-ud-test.conllu']},
#  'ur': {'train': ['UD_Urdu-UDTB/ur_udtb-ud-train.conllu'],
#   'dev': ['UD_Urdu-UDTB/ur_udtb-ud-dev.conllu'],
#   'test': ['UD_Urdu-UDTB/ur_udtb-ud-test.conllu']},
#  'ro': {'dev': ['UD_Romanian-RRT/ro_rrt-ud-dev.conllu',
#    'UD_Romanian-Nonstandard/ro_nonstandard-ud-dev.conllu',
#    'UD_Romanian-SiMoNERo/ro_simonero-ud-dev.conllu'],
#   'test': ['UD_Romanian-RRT/ro_rrt-ud-test.conllu',
#    'UD_Romanian-ArT/ro_art-ud-test.conllu',
#    'UD_Romanian-Nonstandard/ro_nonstandard-ud-test.conllu',
#    'UD_Romanian-SiMoNERo/ro_simonero-ud-test.conllu'],
#   'train': ['UD_Romanian-RRT/ro_rrt-ud-train.conllu',
#    'UD_Romanian-Nonstandard/ro_nonstandard-ud-train.conllu',
#    'UD_Romanian-SiMoNERo/ro_simonero-ud-train.conllu']},
#  'fa': {'test': ['UD_Persian-PerDT/fa_perdt-ud-test.conllu',
#    'UD_Persian-Seraji/fa_seraji-ud-test.conllu'],
#   'train': ['UD_Persian-PerDT/fa_perdt-ud-train.conllu',
#    'UD_Persian-Seraji/fa_seraji-ud-train.conllu'],
#   'dev': ['UD_Persian-PerDT/fa_perdt-ud-dev.conllu',
#    'UD_Persian-Seraji/fa_seraji-ud-dev.conllu']},
#  'apu': {'test': ['UD_Apurina-UFPA/apu_ufpa-ud-test.conllu']},
#  'si': {'test': ['UD_Sinhala-STB/si_stb-ud-test.conllu']},
#  'hu': {'train': ['UD_Hungarian-Szeged/hu_szeged-ud-train.conllu'],
#   'test': ['UD_Hungarian-Szeged/hu_szeged-ud-test.conllu'],
#   'dev': ['UD_Hungarian-Szeged/hu_szeged-ud-dev.conllu']},
#  'hi': {'test': ['UD_Hindi-HDTB/hi_hdtb-ud-test.conllu',
#    'UD_Hindi-PUD/hi_pud-ud-test.conllu'],
#   'train': ['UD_Hindi-HDTB/hi_hdtb-ud-train.conllu'],
#   'dev': ['UD_Hindi-HDTB/hi_hdtb-ud-dev.conllu']},
#  'lzh': {'dev': ['UD_Classical_Chinese-Kyoto/lzh_kyoto-ud-dev.conllu'],
#   'train': ['UD_Classical_Chinese-Kyoto/lzh_kyoto-ud-train.conllu'],
#   'test': ['UD_Classical_Chinese-Kyoto/lzh_kyoto-ud-test.conllu']},
#  'koi': {'test': ['UD_Komi_Permyak-UH/koi_uh-ud-test.conllu'],
#   'train': ['UD_Komi_Permyak-UH/koi_uh-ud-train.conllu']},
#  'fo': {'dev': ['UD_Faroese-FarPaHC/fo_farpahc-ud-dev.conllu'],
#   'test': ['UD_Faroese-FarPaHC/fo_farpahc-ud-test.conllu',
#    'UD_Faroese-OFT/fo_oft-ud-test.conllu'],
#   'train': ['UD_Faroese-FarPaHC/fo_farpahc-ud-train.conllu']},
#  'sa': {'test': ['UD_Sanskrit-Vedic/sa_vedic-ud-test.conllu',
#    'UD_Sanskrit-UFAL/sa_ufal-ud-test.conllu'],
#   'train': ['UD_Sanskrit-Vedic/sa_vedic-ud-train.conllu']},
#  'olo': {'test': ['UD_Livvi-KKPP/olo_kkpp-ud-test.conllu'],
#   'train': ['UD_Livvi-KKPP/olo_kkpp-ud-train.conllu']},
#  'ar': {'train': ['UD_Arabic-NYUAD/ar_nyuad-ud-train.conllu',
#    'UD_Arabic-PADT/ar_padt-ud-train.conllu'],
#   'dev': ['UD_Arabic-NYUAD/ar_nyuad-ud-dev.conllu',
#    'UD_Arabic-PADT/ar_padt-ud-dev.conllu'],
#   'test': ['UD_Arabic-NYUAD/ar_nyuad-ud-test.conllu',
#    'UD_Arabic-PUD/ar_pud-ud-test.conllu',
#    'UD_Arabic-PADT/ar_padt-ud-test.conllu']},
#  'wo': {'test': ['UD_Wolof-WTB/wo_wtb-ud-test.conllu'],
#   'dev': ['UD_Wolof-WTB/wo_wtb-ud-dev.conllu'],
#   'train': ['UD_Wolof-WTB/wo_wtb-ud-train.conllu']},
#  'bg': {'test': ['UD_Bulgarian-BTB/bg_btb-ud-test.conllu'],
#   'train': ['UD_Bulgarian-BTB/bg_btb-ud-train.conllu'],
#   'dev': ['UD_Bulgarian-BTB/bg_btb-ud-dev.conllu']},
#  'bor': {'test': ['UD_Bororo-BDT/bor_bdt-ud-test.conllu']},
#  'aqz': {'test': ['UD_Akuntsu-TuDeT/aqz_tudet-ud-test.conllu']},
#  'mpu': {'test': ['UD_Makurap-TuDeT/mpu_tudet-ud-test.conllu']},
#  'xnr': {'test': ['UD_Kangri-KDTB/xnr_kdtb-ud-test.conllu']},
#  'ml': {'test': ['UD_Malayalam-UFAL/ml_ufal-ud-test.conllu']},
#  'bn': {'test': ['UD_Bengali-BRU/bn_bru-ud-test.conllu']},
#  'br': {'test': ['UD_Breton-KEB/br_keb-ud-test.conllu']},
#  'nap': {'test': ['UD_Neapolitan-RB/nap_rb-ud-test.conllu']},
#  'te': {'train': ['UD_Telugu-MTG/te_mtg-ud-train.conllu'],
#   'test': ['UD_Telugu-MTG/te_mtg-ud-test.conllu'],
#   'dev': ['UD_Telugu-MTG/te_mtg-ud-dev.conllu']},
#  'yue': {'test': ['UD_Cantonese-HK/yue_hk-ud-test.conllu']},
#  'qtd': {'test': ['UD_Turkish_German-SAGT/qtd_sagt-ud-test.conllu'],
#   'dev': ['UD_Turkish_German-SAGT/qtd_sagt-ud-dev.conllu'],
#   'train': ['UD_Turkish_German-SAGT/qtd_sagt-ud-train.conllu']},
#  'eme': {'test': ['UD_Teko-TuDeT/eme_tudet-ud-test.conllu']},
#  'qpm': {'dev': ['UD_Pomak-Philotis/qpm_philotis-ud-dev.conllu'],
#   'train': ['UD_Pomak-Philotis/qpm_philotis-ud-train.conllu'],
#   'test': ['UD_Pomak-Philotis/qpm_philotis-ud-test.conllu']},
#  'cu': {'dev': ['UD_Old_Church_Slavonic-PROIEL/cu_proiel-ud-dev.conllu'],
#   'test': ['UD_Old_Church_Slavonic-PROIEL/cu_proiel-ud-test.conllu'],
#   'train': ['UD_Old_Church_Slavonic-PROIEL/cu_proiel-ud-train.conllu']},
#  'krl': {'test': ['UD_Karelian-KKPP/krl_kkpp-ud-test.conllu']},
#  'qaf': {'dev': ['UD_Maghrebi_Arabic_French-Arabizi/qaf_arabizi-ud-dev.conllu'],
#   'train': ['UD_Maghrebi_Arabic_French-Arabizi/qaf_arabizi-ud-train.conllu'],
#   'test': ['UD_Maghrebi_Arabic_French-Arabizi/qaf_arabizi-ud-test.conllu']},
#  'hsb': {'train': ['UD_Upper_Sorbian-UFAL/hsb_ufal-ud-train.conllu'],
#   'test': ['UD_Upper_Sorbian-UFAL/hsb_ufal-ud-test.conllu']},
#  'da': {'train': ['UD_Danish-DDT/da_ddt-ud-train.conllu'],
#   'dev': ['UD_Danish-DDT/da_ddt-ud-dev.conllu'],
#   'test': ['UD_Danish-DDT/da_ddt-ud-test.conllu']},
#  'azz': {'test': ['UD_Highland_Puebla_Nahuatl-ITML/azz_itml-ud-test.conllu']},
#  'ajp': {'test': ['UD_South_Levantine_Arabic-MADAR/ajp_madar-ud-test.conllu']},
#  'kpv': {'train': ['UD_Komi_Zyrian-Lattice/kpv_lattice-ud-train.conllu'],
#   'test': ['UD_Komi_Zyrian-Lattice/kpv_lattice-ud-test.conllu',
#    'UD_Komi_Zyrian-IKDP/kpv_ikdp-ud-test.conllu']},
#  'nhi': {'test': ['UD_Western_Sierra_Puebla_Nahuatl-ITML/nhi_itml-ud-test.conllu']},
#  'nyq': {'test': ['UD_Nayini-AHA/nyq_aha-ud-test.conllu']},
#  'qfn': {'test': ['UD_Frisian_Dutch-Fame/qfn_fame-ud-test.conllu']},
#  'myu': {'test': ['UD_Munduruku-TuDeT/myu_tudet-ud-test.conllu']},
#  'hit': {'test': ['UD_Hittite-HitTB/hit_hittb-ud-test.conllu']},
#  'gv': {'test': ['UD_Manx-Cadhan/gv_cadhan-ud-test.conllu'],
#   'train': ['UD_Manx-Cadhan/gv_cadhan-ud-train.conllu']},
#  'ky': {'train': ['UD_Kyrgyz-KTMU/ky_ktmu-ud-train.conllu'],
#   'test': ['UD_Kyrgyz-KTMU/ky_ktmu-ud-test.conllu']},
#  'sms': {'test': ['UD_Skolt_Sami-Giellagas/sms_giellagas-ud-test.conllu'],
#   'train': ['UD_Skolt_Sami-Giellagas/sms_giellagas-ud-train.conllu']},
#  'lij': {'train': ['UD_Ligurian-GLT/lij_glt-ud-train.conllu'],
#   'test': ['UD_Ligurian-GLT/lij_glt-ud-test.conllu']},
#  'af': {'dev': ['UD_Afrikaans-AfriBooms/af_afribooms-ud-dev.conllu'],
#   'test': ['UD_Afrikaans-AfriBooms/af_afribooms-ud-test.conllu'],
#   'train': ['UD_Afrikaans-AfriBooms/af_afribooms-ud-train.conllu']},
#  'arr': {'test': ['UD_Karo-TuDeT/arr_tudet-ud-test.conllu']},
#  'otk': {'test': ['UD_Old_Turkish-Tonqq/otk_tonqq-ud-test.conllu']},
#  'tpn': {'test': ['UD_Tupinamba-TuDeT/tpn_tudet-ud-test.conllu']},
#  'be': {'train': ['UD_Belarusian-HSE/be_hse-ud-train.conllu'],
#   'dev': ['UD_Belarusian-HSE/be_hse-ud-dev.conllu'],
#   'test': ['UD_Belarusian-HSE/be_hse-ud-test.conllu']},
#  'cop': {'train': ['UD_Coptic-Scriptorium/cop_scriptorium-ud-train.conllu'],
#   'dev': ['UD_Coptic-Scriptorium/cop_scriptorium-ud-dev.conllu'],
#   'test': ['UD_Coptic-Scriptorium/cop_scriptorium-ud-test.conllu']},
#  'sah': {'test': ['UD_Yakut-YKTDT/sah_yktdt-ud-test.conllu']},
#  'abq': {'test': ['UD_Abaza-ATB/abq_atb-ud-test.conllu']},
#  'sr': {'train': ['UD_Serbian-SET/sr_set-ud-train.conllu'],
#   'dev': ['UD_Serbian-SET/sr_set-ud-dev.conllu'],
#   'test': ['UD_Serbian-SET/sr_set-ud-test.conllu']},
#  'mdf': {'test': ['UD_Moksha-JR/mdf_jr-ud-test.conllu'],
#   'train': ['UD_Moksha-JR/mdf_jr-ud-train.conllu']},
#  'hyw': {'test': ['UD_Western_Armenian-ArmTDP/hyw_armtdp-ud-test.conllu'],
#   'dev': ['UD_Western_Armenian-ArmTDP/hyw_armtdp-ud-dev.conllu'],
#   'train': ['UD_Western_Armenian-ArmTDP/hyw_armtdp-ud-train.conllu']},
#  'gd': {'dev': ['UD_Scottish_Gaelic-ARCOSG/gd_arcosg-ud-dev.conllu'],
#   'train': ['UD_Scottish_Gaelic-ARCOSG/gd_arcosg-ud-train.conllu'],
#   'test': ['UD_Scottish_Gaelic-ARCOSG/gd_arcosg-ud-test.conllu']},
#  'kfm': {'test': ['UD_Khunsari-AHA/kfm_aha-ud-test.conllu']},
#  'ug': {'test': ['UD_Uyghur-UDT/ug_udt-ud-test.conllu'],
#   'train': ['UD_Uyghur-UDT/ug_udt-ud-train.conllu'],
#   'dev': ['UD_Uyghur-UDT/ug_udt-ud-dev.conllu']},
#  'ckt': {'test': ['UD_Chukchi-HSE/ckt_hse-ud-test.conllu']},
#  'xav': {'test': ['UD_Xavante-XDT/xav_xdt-ud-test.conllu']}}

# %%
len(_UD_DATASETS.keys())
# Out:
# 148

# %%
_UD_DATASETS.keys()
# Out:
# dict_keys(['akk', 'hy', 'cy', 'aln', 'no', 'orv', 'en', 'sq', 'fr', 'xcl', 'sl', 'he', 'gub', 'kmr', 'it', 'tr', 'fi', 'id', 'uk', 'nl', 'pl', 'pt', 'kk', 'la', 'jaa', 'es', 'bxr', 'urb', 'ko', 'is', 'et', 'hr', 'got', 'fro', 'swl', 'gsw', 'frm', 'aii', 'sme', 'pcm', 'de', 'lv', 'zh', 'ga', 'sjo', 'tl', 'bm', 'lt', 'grc', 'gl', 'ht', 'ceb', 'vi', 'am', 'el', 'ca', 'ru', 'vep', 'soj', 'sv', 'ess', 'cs', 'bej', 'myv', 'mk', 'bho', 'say', 'xum', 'th', 'mr', 'eu', 'sk', 'jv', 'quc', 'ja', 'gn', 'yo', 'wbp', 'nds', 'ta', 'ka', 'mt', 'yrl', 'sga', 'hbo', 'tt', 'gun', 'ur', 'ro', 'fa', 'apu', 'si', 'hu', 'hi', 'lzh', 'koi', 'fo', 'sa', 'olo', 'ar', 'wo', 'bg', 'bor', 'aqz', 'mpu', 'xnr', 'ml', 'bn', 'br', 'nap', 'te', 'yue', 'qtd', 'eme', 'qpm', 'cu', 'krl', 'qaf', 'hsb', 'da', 'azz', 'ajp', 'kpv', 'nhi', 'nyq', 'qfn', 'myu', 'hit', 'gv', 'ky', 'sms', 'lij', 'af', 'arr', 'otk', 'tpn', 'be', 'cop', 'sah', 'abq', 'sr', 'mdf', 'hyw', 'gd', 'kfm', 'ug', 'ckt', 'xav'])

# %%
# Print the list with each element on a separate line
print("[")
for item in sorted(_UD_DATASETS.keys()):
    print(f'"{item}",')
print("]")
# Out:
# [
# "abq",
# "af",
# "aii",
# "ajp",
# "akk",
# "aln",
# "am",
# "apu",
# "aqz",
# "ar",
# "arr",
# "azz",
# "be",
# "bej",
# "bg",
# "bho",
# "bm",
# "bn",
# "bor",
# "br",
# "bxr",
# "ca",
# "ceb",
# "ckt",
# "cop",
# "cs",
# "cu",
# "cy",
# "da",
# "de",
# "el",
# "eme",
# "en",
# "es",
# "ess",
# "et",
# "eu",
# "fa",
# "fi",
# "fo",
# "fr",
# "frm",
# "fro",
# "ga",
# "gd",
# "gl",
# "gn",
# "got",
# "grc",
# "gsw",
# "gub",
# "gun",
# "gv",
# "hbo",
# "he",
# "hi",
# "hit",
# "hr",
# "hsb",
# "ht",
# "hu",
# "hy",
# "hyw",
# "id",
# "is",
# "it",
# "ja",
# "jaa",
# "jv",
# "ka",
# "kfm",
# "kk",
# "kmr",
# "ko",
# "koi",
# "kpv",
# "krl",
# "ky",
# "la",
# "lij",
# "lt",
# "lv",
# "lzh",
# "mdf",
# "mk",
# "ml",
# "mpu",
# "mr",
# "mt",
# "myu",
# "myv",
# "nap",
# "nds",
# "nhi",
# "nl",
# "no",
# "nyq",
# "olo",
# "orv",
# "otk",
# "pcm",
# "pl",
# "pt",
# "qaf",
# "qfn",
# "qpm",
# "qtd",
# "quc",
# "ro",
# "ru",
# "sa",
# "sah",
# "say",
# "sga",
# "si",
# "sjo",
# "sk",
# "sl",
# "sme",
# "sms",
# "soj",
# "sq",
# "sr",
# "sv",
# "swl",
# "ta",
# "te",
# "th",
# "tl",
# "tpn",
# "tr",
# "tt",
# "ug",
# "uk",
# "ur",
# "urb",
# "vep",
# "vi",
# "wbp",
# "wo",
# "xav",
# "xcl",
# "xnr",
# "xum",
# "yo",
# "yrl",
# "yue",
# "zh",
# ]

# %%
x = [
            "en",
            "nl",
            "de",
            "it",
            "fr",
            "es",
            "ru",
            "sv",
            "no",
            "da",
            "nds",
            "akk",
            "hy",
            "cy",
            "orv",
            "sq",
            # "qhe", code-switching
            "sl",
            "gub",
            "kmr",
            "tr",
            "fi",
            "id",
            "uk",
            "pl",
            "pt",
            "kk",
            "la",
            "fro",
            "bxr",
            "urb",
            "ko",
            "et",
            "hr",
            "got",
            # "swl", sign language
            "gsw",
            "aii",
            "sme",
            "pcm",
            "lv",
            "zh",
            "tl",
            "bm",
            "lt",
            "gl",
            "vi",
            # "am", <10
            "el",
            "ca",
            # "soj", <10
            # "ess", empty (not token-level, but morpheme-level)
            "cs",
            # "bej", # no written data, phonetic-ish transcription
            "myv",
            "bho",
            "th",
            "mr",
            "eu",
            "sk",
            "quc",
            "yo",
            "wbp",
            "ta",
            "mt",
            "grc",
            "is",
            "gun",
            "ur",
            "ro",
            "fa",
            "apu",
            "ja",
            "hu",
            "hi",
            "lzh",
            "koi",
            "fo",
            "sa",
            "olo",
            "ar",
            "wo",
            "bg",
            "aqz",
            "mpu",
            "xnr",
            "br",
            "te",
            "yue",
            # "qtd", code-switching
            "cu",
            "krl",
            "hsb",
            "ajp",
            "kpv",
            "ga",
            "nyq",
            # "qfn", code-switching
            "myu",
            "gv",
            "sms",
            "af",
            "otk",
            "tpn",
            "be",
            # "cop", <10
            "sr",
            "mdf",
            "hyw",
            "gd",
            "kfm",
            "he",
            "ug",
            "ckt",
          ]

# %%
len(x)
# Out:
# 105

# %%
import os

original_directory = os.getcwd()

new_directory = '/Users/jplayacan/.cache/huggingface/datasets/downloads/extracted/8453fbfded7739b8a75b017ff719af23ed073e893f0988874aac9d45a29b54b1/ud-treebanks-v2.13/'
os.chdir(new_directory)

_UD_DATASETS = {}
for dirname in os.listdir():
    if not os.path.isdir(dirname):
        continue
    lang, dataset = dirname.replace("UD_", "").split("-")
    for filename in os.listdir(dirname):
        if not filename.endswith(".conllu"):
            continue
        id_, split = filename.replace(".conllu", "").split("-ud-")
        langid, dataid = id_.split("_")
        if split == "train":  # Check if the split is "test"
            print(lang, dataset, langid, dataid, split)
            if langid not in _UD_DATASETS:
                _UD_DATASETS[langid] = {}
            if split not in _UD_DATASETS[langid]:
                _UD_DATASETS[langid][split] = []
os.chdir(original_directory)
# Out:
# Armenian ArmTDP hy armtdp train
# Welsh CCG cy ccg train
# Norwegian Nynorsk no nynorsk train
# Old_East_Slavic TOROT orv torot train
# English LinES en lines train
# French Sequoia fr sequoia train
# Old_East_Slavic Ruthenian orv ruthenian train
# Slovenian SST sl sst train
# Hebrew IAHLTwiki he iahltwiki train
# Kurmanji MG kmr mg train
# Finnish FTB fi ftb train
# Indonesian GSD id gsd train
# Ukrainian IU uk iu train
# English Atis en atis train
# Dutch LassySmall nl lassysmall train
# Polish PDB pl pdb train
# Turkish Kenet tr kenet train
# Portuguese Bosque pt bosque train
# Kazakh KTB kk ktb train
# Italian PoSTWITA it postwita train
# Latin ITTB la ittb train
# Buryat BDT bxr bdt train
# Italian ParlaMint it parlamint train
# Latin Perseus la perseus train
# Icelandic GC is gc train
# Estonian EDT et edt train
# Croatian SET hr set train
# Gothic PROIEL got proiel train
# Old_French PROFITEROLE fro profiterole train
# Turkish FrameNet tr framenet train
# Latin LLCT la llct train
# Turkish Atis tr atis train
# Italian ISDT it isdt train
# North_Sami Giella sme giella train
# Norwegian Bokmaal no bokmaal train
# French ParisStories fr parisstories train
# Naija NSC pcm nsc train
# English ESLSpok en eslspok train
# Italian MarkIT it markit train
# Latvian LVTB lv lvtb train
# Chinese GSDSimp zh gsdsimp train
# Lithuanian ALKSNIS lt alksnis train
# Ancient_Greek PTNK grc ptnk train
# Galician CTG gl ctg train
# Vietnamese VTB vi vtb train
# Korean GSD ko gsd train
# Greek GDT el gdt train
# German HDT de hdt train
# Spanish GSD es gsd train
# Catalan AnCora ca ancora train
# Russian Poetry ru poetry train
# English EWT en ewt train
# Old_East_Slavic RNC orv rnc train
# Swedish LinES sv lines train
# Russian SynTagRus ru syntagrus train
# Czech PDT cs pdt train
# Italian VIT it vit train
# Erzya JR myv jr train
# Armenian BSUT hy bsut train
# Polish LFG pl lfg train
# Marathi UFAL mr ufal train
# Basque BDT eu bdt train
# Slovak SNK sk snk train
# Japanese GSDLUW ja gsdluw train
# Russian Taiga ru taiga train
# Tamil TTB ta ttb train
# Spanish AnCora es ancora train
# Maltese MUDT mt mudt train
# Finnish TDT fi tdt train
# French Rhapsodie fr rhapsodie train
# Indonesian CSUI id csui train
# Ancient_Greek Perseus grc perseus train
# Old_East_Slavic Birchbark orv birchbark train
# Ancient_Hebrew PTNK hbo ptnk train
# Icelandic IcePaHC is icepahc train
# Urdu UDTB ur udtb train
# Romanian RRT ro rrt train
# Latin PROIEL la proiel train
# Persian PerDT fa perdt train
# French ParTUT fr partut train
# Icelandic Modern is modern train
# Hungarian Szeged hu szeged train
# Hindi HDTB hi hdtb train
# Classical_Chinese Kyoto lzh kyoto train
# Komi_Permyak UH koi uh train
# Faroese FarPaHC fo farpahc train
# Sanskrit Vedic sa vedic train
# Turkish IMST tr imst train
# Portuguese Porttinari pt porttinari train
# Lithuanian HSE lt hse train
# Slovenian SSJ sl ssj train
# Livvi KKPP olo kkpp train
# Swedish Talbanken sv talbanken train
# Arabic NYUAD ar nyuad train
# English GUMReddit en gumreddit train
# Italian ParTUT it partut train
# Czech FicTree cs fictree train
# Wolof WTB wo wtb train
# Bulgarian BTB bg btb train
# Portuguese PetroGold pt petrogold train
# Turkish Penn tr penn train
# Japanese BCCWJ ja bccwj train
# Italian TWITTIRO it twittiro train
# Ancient_Greek PROIEL grc proiel train
# Czech CAC cs cac train
# Japanese GSD ja gsd train
# Telugu MTG te mtg train
# Italian Old it old train
# Korean Kaist ko kaist train
# Turkish_German SAGT qtd sagt train
# English GUM en gum train
# Pomak Philotis qpm philotis train
# Romanian Nonstandard ro nonstandard train
# German GSD de gsd train
# Old_Church_Slavonic PROIEL cu proiel train
# Maghrebi_Arabic_French Arabizi qaf arabizi train
# Portuguese CINTIL pt cintil train
# Upper_Sorbian UFAL hsb ufal train
# Danish DDT da ddt train
# Galician TreeGal gl treegal train
# Komi_Zyrian Lattice kpv lattice train
# Irish IDT ga idt train
# Manx Cadhan gv cadhan train
# Kyrgyz KTMU ky ktmu train
# Skolt_Sami Giellagas sms giellagas train
# Persian Seraji fa seraji train
# Ligurian GLT lij glt train
# Afrikaans AfriBooms af afribooms train
# Czech CLTT cs cltt train
# French GSD fr gsd train
# Irish TwittIrish ga twittirish train
# Dutch Alpino nl alpino train
# Chinese GSD zh gsd train
# Romanian SiMoNERo ro simonero train
# Belarusian HSE be hse train
# Coptic Scriptorium cop scriptorium train
# Serbian SET sr set train
# Turkish Tourism tr tourism train
# Estonian EWT et ewt train
# Moksha JR mdf jr train
# Western_Armenian ArmTDP hyw armtdp train
# Scottish_Gaelic ARCOSG gd arcosg train
# Portuguese GSD pt gsd train
# Russian GSD ru gsd train
# Turkish BOUN tr boun train
# Arabic PADT ar padt train
# Hebrew HTB he htb train
# Greek GUD el gud train
# English ParTUT en partut train
# Uyghur UDT ug udt train
# Latin UDante la udante train
# Japanese BCCWJLUW ja bccwjluw train

# %%
# Print the list with each element on a separate line
print("[")
for item in sorted(_UD_DATASETS.keys()):
    print(f'"{item}",')
print("]")
# Out:
# [
# "af",
# "ar",
# "be",
# "bg",
# "bxr",
# "ca",
# "cop",
# "cs",
# "cu",
# "cy",
# "da",
# "de",
# "el",
# "en",
# "es",
# "et",
# "eu",
# "fa",
# "fi",
# "fo",
# "fr",
# "fro",
# "ga",
# "gd",
# "gl",
# "got",
# "grc",
# "gv",
# "hbo",
# "he",
# "hi",
# "hr",
# "hsb",
# "hu",
# "hy",
# "hyw",
# "id",
# "is",
# "it",
# "ja",
# "kk",
# "kmr",
# "ko",
# "koi",
# "kpv",
# "ky",
# "la",
# "lij",
# "lt",
# "lv",
# "lzh",
# "mdf",
# "mr",
# "mt",
# "myv",
# "nl",
# "no",
# "olo",
# "orv",
# "pcm",
# "pl",
# "pt",
# "qaf",
# "qpm",
# "qtd",
# "ro",
# "ru",
# "sa",
# "sk",
# "sl",
# "sme",
# "sms",
# "sr",
# "sv",
# "ta",
# "te",
# "tr",
# "ug",
# "uk",
# "ur",
# "vi",
# "wo",
# "zh",
# ]

# %%
len(_UD_DATASETS.keys())
# Out:
# 83

# %%
_UD_DATASETS
# Out:
# {'hy': {'train': []},
#  'cy': {'train': []},
#  'no': {'train': []},
#  'orv': {'train': []},
#  'en': {'train': []},
#  'fr': {'train': []},
#  'sl': {'train': []},
#  'he': {'train': []},
#  'kmr': {'train': []},
#  'fi': {'train': []},
#  'id': {'train': []},
#  'uk': {'train': []},
#  'nl': {'train': []},
#  'pl': {'train': []},
#  'tr': {'train': []},
#  'pt': {'train': []},
#  'kk': {'train': []},
#  'it': {'train': []},
#  'la': {'train': []},
#  'bxr': {'train': []},
#  'is': {'train': []},
#  'et': {'train': []},
#  'hr': {'train': []},
#  'got': {'train': []},
#  'fro': {'train': []},
#  'sme': {'train': []},
#  'pcm': {'train': []},
#  'lv': {'train': []},
#  'zh': {'train': []},
#  'lt': {'train': []},
#  'grc': {'train': []},
#  'gl': {'train': []},
#  'vi': {'train': []},
#  'ko': {'train': []},
#  'el': {'train': []},
#  'de': {'train': []},
#  'es': {'train': []},
#  'ca': {'train': []},
#  'ru': {'train': []},
#  'sv': {'train': []},
#  'cs': {'train': []},
#  'myv': {'train': []},
#  'mr': {'train': []},
#  'eu': {'train': []},
#  'sk': {'train': []},
#  'ja': {'train': []},
#  'ta': {'train': []},
#  'mt': {'train': []},
#  'hbo': {'train': []},
#  'ur': {'train': []},
#  'ro': {'train': []},
#  'fa': {'train': []},
#  'hu': {'train': []},
#  'hi': {'train': []},
#  'lzh': {'train': []},
#  'koi': {'train': []},
#  'fo': {'train': []},
#  'sa': {'train': []},
#  'olo': {'train': []},
#  'ar': {'train': []},
#  'wo': {'train': []},
#  'bg': {'train': []},
#  'te': {'train': []},
#  'qtd': {'train': []},
#  'qpm': {'train': []},
#  'cu': {'train': []},
#  'qaf': {'train': []},
#  'hsb': {'train': []},
#  'da': {'train': []},
#  'kpv': {'train': []},
#  'ga': {'train': []},
#  'gv': {'train': []},
#  'ky': {'train': []},
#  'sms': {'train': []},
#  'lij': {'train': []},
#  'af': {'train': []},
#  'be': {'train': []},
#  'cop': {'train': []},
#  'sr': {'train': []},
#  'mdf': {'train': []},
#  'hyw': {'train': []},
#  'gd': {'train': []},
#  'ug': {'train': []}}
